# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/"

# %%
from SciServer import CasJobs as cj
import pandas as pd
import numpy as np
import requests
import time
import pickle
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
pd.set_option('display.max_rows', 20)

# Iniciar sesión
from SciServer import Authentication
Authentication.login(UserName = "Alberto_2002", Password = "#Blackie2002")
# Out:
# 'b60af325865141a9bd6e7aab5be23b34'

# %%
# Parámetros iniciales
batch_size_inicial = 50000       # tamaño inicial del lote
min_batch_size = 50000           # tamaño mínimo de lote permitido
max_retries = 10                 # máximo número de reintentos por lote
offset = 0                       # registro inicial a recuperar, dejamos la variable por si hace falta aunque por ahora no hace mucho
all_results = []
batch_results = []

while offset < 1:

    with open('extra/redshift_init.pickle', 'rb') as handle:
        redshift_init = pickle.load(handle)

    redshift_init = float(str(redshift_init)[:8]) # Solo se toman los primeros 7 digitos porque si no se excede el límite de la consulta
    # redshift_init = 0 # Arbitrario
    current_batch_size = batch_size_inicial
    retries = 0
    success = False

    # Intentar ejecutar el query con el tamaño de lote actual. Si hay error, se reduce el lote y se reintenta.             2.121375e-07
    while not success and retries < max_retries:
        sql_query = f"""
        SELECT
            p.objid,
            s.specObjID,
            dbo.fGetUrlFitsSpectrum(s.specObjID) AS fits_url,
            s.z AS redshift
        FROM 
            PhotoObj AS p
        JOIN 
            SpecObj AS s ON s.bestobjid = p.objid
        WHERE 
            s.z BETWEEN 0 AND 9
            AND s.zWarning = 0
            AND (s.class = 'QSO' OR s.class = 'GALAXY')
        ORDER BY p.objid
        OFFSET 0 ROWS
        FETCH NEXT {current_batch_size} ROWS ONLY
        """
        try:
            batch_results = pd.DataFrame(cj.executeQuery(sql_query, context="DR18"))
            success = True
            all_results.append(batch_results)
            offset += len(batch_results)

            with open('extra/all_results.pickle', 'wb') as handle:
                pickle.dump(all_results, handle)
            print(f"Recuperados {offset} registros hasta ahora.")

            ultimo_redshift = batch_results["redshift"].iloc[-1]

            ultimo_redshift = float(str(ultimo_redshift)[:8])
            print(f"Redshift inicial: {redshift_init}")
            print(f"Redshift último: {ultimo_redshift}")
            if ultimo_redshift == redshift_init:    # Si el redshift no cambió, se incrementa un poco para evitar loops infinitos
                ultimo_redshift = ultimo_redshift + 0.000002
                print(f"Se incrementó el redshift a {ultimo_redshift}")

            with open('extra/redshift_init.pickle', 'wb') as handle:
                pickle.dump(ultimo_redshift, handle)

        except Exception as e:
            print(f"Error en la consulta con batch_size = {current_batch_size}: {e}")
            # Reducir el tamaño del lote, pero sin bajar de min_batch_size
            current_batch_size = max(min_batch_size, current_batch_size // 2)
            retries += 1
            time.sleep(2)  # Esperar un poco antes de reintentar

    if len(batch_results) == 0:
        print("No hay más registros para recuperar.")
        break

    if retries == max_retries:
        print("No se pudo recuperar el batch tras varios reintentos. Terminando.")
        break
# Out:
# Recuperados 50000 registros hasta ahora.
# Redshift inicial: 7.042325
# Redshift último: 0.555069

# %%
with open('extra/all_results.pickle', 'rb') as handle:
    all_results = pickle.load(handle)

# Combinar todos los resultados (suponiendo que cada batch es un DataFrame)
combined_results = pd.concat(all_results, ignore_index=True)
print(f"Total de registros recuperados: {len(combined_results)}")

# Extraer las URLs de los archivos FITS
fits_urls = combined_results["fits_url"].tolist()
print(f"Se han obtenido {len(fits_urls)} URLs de FITS.")

ultimo_redshift = all_results[len(all_results)-2]["redshift"].iloc[0]
print(f"Último redshift recuperado: {ultimo_redshift:.7f}")

with open('extra/redshift_init.pickle', 'wb') as handle:
    pickle.dump(ultimo_redshift, handle)
# Out:
# Total de registros recuperados: 50000
# Se han obtenido 50000 URLs de FITS.
# Último redshift recuperado: 0.3996609

# %%
import os

# Directorio de descarga
output_dir = r"spectrums"
os.makedirs(output_dir, exist_ok=True)

archivos_descargados = []

def download_file(url):
    filename = os.path.basename(url)
    local_path = os.path.join(output_dir, filename)
    
    # Saltar si ya se descargó este archivo
    if os.path.exists(local_path):
        print(f"Saltando {filename} (ya descargado).")
        return filename, None
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        with open(local_path, "wb") as f:
            f.write(response.content)
        print(f"Descargado: {filename}")
        return filename, None
    except Exception as e:
        print(f"Error al descargar {url}: {e}")
        return filename, e

# Número de descargas en paralelo
paralelo = 100
i=0

with ThreadPoolExecutor(max_workers=paralelo) as executor:
    future_to_url = {executor.submit(download_file, url): url for url in fits_urls}
    
    for future in as_completed(future_to_url):
        i+=1
        print(f"Descargando archivo {i} de {len(fits_urls)}")
        filename, error = future.result()
        if error is None:
            archivos_descargados.append(filename)

print("Descarga finalizada")
# Out:
# Descargado: spec-1529-52930-0446.fitsDescargado: spec-0408-51821-0100.fits
#
# Descargando archivo 1 de 50000
# Descargando archivo 2 de 50000
# Descargado: spec-1242-52901-0438.fits
# Descargando archivo 3 de 50000
# Descargado: spec-0413-51821-0575.fits
# Descargando archivo 4 de 50000
# Descargado: spec-1242-52901-0472.fits
# Descargando archivo 5 de 50000
# Descargado: spec-0805-52586-0426.fits
# Descargando archivo 6 de 50000
# Descargado: spec-1242-52901-0477.fits
# Descargando archivo 7 de 50000
# Descargado: spec-0416-51811-0472.fits
# Descargando archivo 8 de 50000
# Descargado: spec-3650-55244-0851.fits
# Descargando archivo 9 de 50000
# Descargado: spec-0714-52201-0542.fits
# Descargando archivo 10 de 50000
# Descargado: spec-0809-52647-0443.fits
# Descargando archivo 11 de 50000
# Descargado: spec-7825-57030-0923.fits
# Descargando archivo 12 de 50000
# Descargado: spec-2639-54116-0471.fits
# Descargando archivo 13 de 50000
# Descargado: spec-1062-52619-0422.fits
# Descargando archivo 14 de 50000
# Descargado: spec-0413-51821-0379.fits
# Descargando archivo 15 de 50000
# Descargado: spec-6782-56572-0673.fits
# Descargando archivo 16 de 50000
# Descargado: spec-4286-55499-0322.fits
# Descargando archivo 17 de 50000
# Descargado: spec-0416-51811-0417.fits
# Descargando archivo 18 de 50000
# Descargado: spec-4311-55506-0281.fits
# Descargando archivo 19 de 50000
# Descargado: spec-1633-52998-0148.fits
# Descargando archivo 20 de 50000
# Descargado: spec-0414-51869-0401.fits
# Descargando archivo 21 de 50000
# Descargado: spec-1633-52998-0112.fits
# Descargando archivo 22 de 50000
# Descargado: spec-1242-52901-0429.fits
# Descargando archivo 23 de 50000
# Descargado: spec-1242-52901-0491.fits
# Descargando archivo 24 de 50000
# Descargado: spec-0670-52520-0374.fits
# Descargando archivo 25 de 50000
# Descargado: spec-1633-52998-0509.fits
# Descargando archivo 26 de 50000
# Descargado: spec-1633-52998-0500.fits
# Descargado: spec-1243-52930-0429.fits
# Descargado: spec-3651-55247-0419.fits
# Descargando archivo 27 de 50000
# Descargando archivo 28 de 50000
# Descargando archivo 29 de 50000
# Descargado: spec-1529-52930-0460.fits
# Descargando archivo 30 de 50000
# Descargado: spec-1529-52930-0451.fits
# Descargando archivo 31 de 50000
# Descargado: spec-1529-52930-0452.fits
# Descargando archivo 32 de 50000
# Descargado: spec-1243-52930-0472.fits
# Descargando archivo 33 de 50000
# Descargado: spec-1529-52930-0412.fits
# Descargando archivo 34 de 50000
# Descargado: spec-0670-52520-0367.fits
# Descargando archivo 35 de 50000
# Descargado: spec-1633-52998-0475.fits
# Descargando archivo 36 de 50000
# Descargado: spec-1242-52901-0508.fits
# Descargando archivo 37 de 50000
# Descargado: spec-1633-52998-0177.fits
# Descargando archivo 38 de 50000
# Descargado: spec-0806-52592-0567.fits
# Descargando archivo 39 de 50000
# Descargado: spec-1518-52937-0546.fits
# Descargando archivo 40 de 50000
# Descargado: spec-1242-52901-0479.fits
# Descargando archivo 41 de 50000
# Descargado: spec-1529-52930-0443.fits
# Descargando archivo 42 de 50000
# Descargado: spec-1633-52998-0173.fits
# Descargando archivo 43 de 50000
# Descargado: spec-1633-52998-0502.fits
# Descargado: spec-1243-52930-0475.fits
# Descargando archivo 44 de 50000
# Descargando archivo 45 de 50000
# Descargado: spec-1632-52996-0595.fits
# Descargado: spec-1243-52930-0474.fits
# Descargando archivo 46 de 50000
# Descargando archivo 47 de 50000
# Descargado: spec-1242-52901-0546.fits
# Descargando archivo 48 de 50000
# Descargado: spec-1529-52930-0371.fits
# Descargando archivo 49 de 50000
# Descargado: spec-1529-52930-0366.fits
# Descargando archivo 50 de 50000
# Descargado: spec-1242-52901-0439.fits
# Descargando archivo 51 de 50000
# Descargado: spec-1632-52996-0591.fits
# Descargando archivo 52 de 50000
# Descargado: spec-1633-52998-0485.fits
# Descargando archivo 53 de 50000
# Descargado: spec-0414-51869-0410.fits
# Descargando archivo 54 de 50000
# Descargado: spec-1243-52930-0431.fits
# Descargando archivo 55 de 50000
# Descargado: spec-0416-51811-0442.fits
# Descargando archivo 56 de 50000
# Descargado: spec-1242-52901-0502.fits
# Descargando archivo 57 de 50000
# Descargado: spec-0382-51816-0368.fits
# Descargando archivo 58 de 50000
# Descargado: spec-1633-52998-0499.fits
# Descargando archivo 59 de 50000
# Descargado: spec-1243-52930-0493.fits
# Descargando archivo 60 de 50000
# Descargado: spec-1242-52901-0478.fits
# Descargando archivo 61 de 50000
# Descargado: spec-1242-52901-0487.fitsDescargado: spec-1633-52998-0494.fits
#
# Descargando archivo 62 de 50000
# Descargando archivo 63 de 50000
# Descargado: spec-1529-52930-0411.fits
# Descargando archivo 64 de 50000
# Descargado: spec-1243-52930-0438.fits
# Descargando archivo 65 de 50000
# Descargado: spec-1242-52901-0471.fits
# Descargando archivo 66 de 50000
# Descargado: spec-1243-52930-0477.fits
# Descargando archivo 67 de 50000
# Descargado: spec-1243-52930-0500.fits
# Descargando archivo 68 de 50000
# Descargado: spec-1242-52901-0468.fits
# Descargando archivo 69 de 50000
# Descargado: spec-2638-54095-0592.fits
# Descargando archivo 70 de 50000
# Descargado: spec-1529-52930-0413.fits
# Descargando archivo 71 de 50000
# Descargado: spec-1529-52930-0457.fits
# Descargando archivo 72 de 50000
# Descargado: spec-1529-52930-0459.fits
# Descargando archivo 73 de 50000
# Descargado: spec-1243-52930-0432.fits
# Descargando archivo 74 de 50000
# Descargado: spec-1633-52998-0400.fits
# Descargando archivo 75 de 50000
# Descargado: spec-1529-52930-0453.fits
# Descargando archivo 76 de 50000
# Descargado: spec-6782-56572-0670.fits
# Descargando archivo 77 de 50000
# Descargado: spec-1242-52901-0503.fits
# Descargando archivo 78 de 50000
# Descargado: spec-1242-52901-0507.fits
# Descargando archivo 79 de 50000
# Descargado: spec-1242-52901-0509.fits
# Descargando archivo 80 de 50000
# Descargado: spec-1633-52998-0120.fits
# Descargando archivo 81 de 50000
# Descargado: spec-1529-52930-0417.fits
# Descargando archivo 82 de 50000
# Descargado: spec-2639-54465-0632.fits
# Descargando archivo 83 de 50000
# Descargado: spec-1529-52930-0499.fits
# Descargado: spec-4261-55503-0085.fits
# Descargando archivo 84 de 50000
# Descargando archivo 85 de 50000
# Descargado: spec-1242-52901-0473.fits
# Descargando archivo 86 de 50000
# Descargado: spec-1243-52930-0487.fits
# Descargando archivo 87 de 50000
# Descargado: spec-1242-52901-0493.fits
# Descargando archivo 88 de 50000
# Descargado: spec-1242-52901-0494.fits
# Descargando archivo 89 de 50000
# Descargado: spec-1243-52930-0494.fits
# Descargando archivo 90 de 50000
# Descargado: spec-1242-52901-0506.fits
# Descargando archivo 91 de 50000
# Descargado: spec-1633-52998-0496.fits
# Descargando archivo 92 de 50000
# Descargado: spec-1242-52901-0461.fits
# Descargando archivo 93 de 50000
# Descargado: spec-1529-52930-0455.fits
# Descargando archivo 94 de 50000
# Descargado: spec-1243-52930-0495.fits
# Descargando archivo 95 de 50000
# Descargado: spec-1633-52998-0493.fits
# Descargando archivo 96 de 50000
# Descargado: spec-1633-52998-0498.fits
# Descargando archivo 97 de 50000
# Descargado: spec-1633-52998-0548.fits
# Descargando archivo 98 de 50000
# Descargado: spec-4240-55455-0338.fits
# Descargando archivo 99 de 50000
# Descargado: spec-1242-52901-0560.fits
# Descargando archivo 100 de 50000
# Descargado: spec-1243-52930-0520.fits
# Descargando archivo 101 de 50000
# Descargado: spec-1242-52901-0542.fits
# Descargando archivo 102 de 50000
# Descargado: spec-1242-52901-0555.fits
# Descargando archivo 103 de 50000
# Descargado: spec-1243-52930-0505.fits
# Descargando archivo 104 de 50000
# Descargado: spec-1529-52930-0498.fits
# Descargando archivo 105 de 50000
# Descargado: spec-1242-52901-0599.fits
# Descargando archivo 106 de 50000
# Descargado: spec-1633-52998-0600.fits
# Descargado: spec-1242-52901-0541.fits
# Descargando archivo 107 de 50000
# Descargando archivo 108 de 50000
# Descargado: spec-1633-52998-0594.fits
# Descargando archivo 109 de 50000
# Descargado: spec-1242-52901-0588.fits
# Descargando archivo 110 de 50000
# Descargado: spec-1633-52998-0591.fits
# Descargando archivo 111 de 50000
# Descargado: spec-1633-52998-0598.fits
# Descargando archivo 112 de 50000
# Descargado: spec-1633-52998-0597.fits
# Descargando archivo 113 de 50000
# Descargado: spec-1242-52901-0594.fits
# Descargando archivo 114 de 50000
# Descargado: spec-1243-52930-0541.fits
# Descargando archivo 115 de 50000
# Descargado: spec-1243-52930-0550.fits
# Descargando archivo 116 de 50000
# Descargado: spec-1242-52901-0638.fits
# Descargando archivo 117 de 50000
# Descargado: spec-1243-52930-0542.fits
# Descargando archivo 118 de 50000
# Descargado: spec-1529-52930-0576.fits
# Descargando archivo 119 de 50000
# Descargado: spec-1243-52930-0588.fits
# Descargando archivo 120 de 50000
# Descargado: spec-1242-52901-0636.fits
# Descargando archivo 121 de 50000
# Descargado: spec-1633-52998-0583.fits
# Descargando archivo 122 de 50000
# Descargado: spec-1243-52930-0560.fits
# Descargando archivo 123 de 50000
# Descargado: spec-1633-52998-0592.fits
# Descargando archivo 124 de 50000
# Descargado: spec-1529-52930-0564.fits
# Descargando archivo 125 de 50000
# Descargado: spec-1633-52998-0079.fits
# Descargando archivo 126 de 50000
# Descargado: spec-1529-52930-0580.fits
# Descargando archivo 127 de 50000
# Descargado: spec-1633-52998-0599.fits
# Descargando archivo 128 de 50000
# Descargado: spec-1529-52930-0577.fits
# Descargando archivo 129 de 50000
# Descargado: spec-1633-52998-0622.fits
# Descargando archivo 130 de 50000
# Descargado: spec-1243-52930-0593.fits
# Descargando archivo 131 de 50000
# Descargado: spec-1633-52998-0626.fits
# Descargando archivo 132 de 50000
# Descargado: spec-1633-52998-0629.fits
# Descargando archivo 133 de 50000
# Descargado: spec-1633-52998-0624.fits
# Descargando archivo 134 de 50000
# Descargado: spec-1243-52930-0635.fits
# Descargando archivo 135 de 50000
# Descargado: spec-1633-52998-0638.fits
# Descargando archivo 136 de 50000
# Descargado: spec-1243-52930-0622.fits
# Descargando archivo 137 de 50000
# Descargado: spec-1633-52998-0625.fits
# Descargando archivo 138 de 50000
# Descargado: spec-1243-52930-0624.fits
# Descargando archivo 139 de 50000
# Descargado: spec-1243-52930-0590.fits
# Descargando archivo 140 de 50000
# Descargado: spec-1529-52930-0616.fits
# Descargando archivo 141 de 50000
# Descargado: spec-1529-52930-0620.fits
# Descargando archivo 142 de 50000
# Descargado: spec-1633-52998-0627.fits
# Descargando archivo 143 de 50000
# Descargado: spec-1243-52930-0625.fits
# Descargando archivo 144 de 50000
# Descargado: spec-1559-53271-0386.fits
# Descargando archivo 145 de 50000
# Descargado: spec-3615-56544-0775.fits
# Descargando archivo 146 de 50000
# Descargado: spec-6780-56605-0866.fits
# Descargando archivo 147 de 50000
# Descargado: spec-6782-56572-0590.fits
# Descargando archivo 148 de 50000
# Descargado: spec-1560-53317-0541.fits
# Descargando archivo 149 de 50000
# Descargado: spec-6781-56274-0990.fits
# Descargando archivo 150 de 50000
# Descargado: spec-6781-56274-0989.fits
# Descargando archivo 151 de 50000
# Descargado: spec-6781-56274-0994.fits
# Descargando archivo 152 de 50000
# Descargado: spec-3650-55244-0764.fits
# Descargando archivo 153 de 50000
# Descargado: spec-1068-52614-0531.fits
# Descargando archivo 154 de 50000
# Descargado: spec-0410-51877-0576.fits
# Descargando archivo 155 de 50000
# Descargado: spec-0410-51877-0574.fits
# Descargando archivo 156 de 50000
# Descargado: spec-0410-51877-0577.fits
# Descargando archivo 157 de 50000
# Descargado: spec-0410-51877-0579.fits
# Descargando archivo 158 de 50000
# Descargado: spec-6781-56575-0991.fits
# Descargando archivo 159 de 50000
# Descargado: spec-9370-58056-0271.fits
# Descargando archivo 160 de 50000
# Descargado: spec-1562-53052-0572.fits
# Descargando archivo 161 de 50000
# Descargado: spec-1562-53052-0526.fits
# Descargando archivo 162 de 50000
# Descargado: spec-1562-53052-0523.fits
# Descargando archivo 163 de 50000
# Descargado: spec-1068-52614-0565.fits
# Descargando archivo 164 de 50000
# Descargado: spec-9370-58056-0236.fits
# Descargando archivo 165 de 50000
# Descargado: spec-9370-58056-0225.fits
# Descargando archivo 166 de 50000
# Descargado: spec-1562-53052-0563.fits
# Descargando archivo 167 de 50000
# Descargado: spec-9370-58056-0231.fits
# Descargando archivo 168 de 50000
# Descargado: spec-1562-53052-0564.fits
# Descargando archivo 169 de 50000
# Descargado: spec-7819-57280-0056.fits
# Descargando archivo 170 de 50000
# Descargado: spec-9370-58056-0200.fits
# Descargando archivo 171 de 50000
# Descargado: spec-1068-52614-0578.fits
# Descargando archivo 172 de 50000
# Descargado: spec-7820-56984-0744.fits
# Descargando archivo 173 de 50000
# Descargado: spec-7820-56984-0794.fits
# Descargando archivo 174 de 50000
# Descargado: spec-0708-52175-0610.fits
# Descargando archivo 175 de 50000
# Descargado: spec-1562-53052-0577.fits
# Descargando archivo 176 de 50000
# Descargado: spec-9370-58056-0195.fitsDescargado: spec-4242-55476-0830.fits
#
# Descargando archivo 177 de 50000
# Descargando archivo 178 de 50000
# Descargado: spec-4242-55476-0831.fits
# Descargando archivo 179 de 50000
# Descargado: spec-7819-57280-0057.fits
# Descargando archivo 180 de 50000
# Descargado: spec-4242-55476-0833.fits
# Descargando archivo 181 de 50000
# Descargado: spec-4242-55476-0872.fits
# Descargando archivo 182 de 50000
# Descargado: spec-7820-56984-0797.fits
# Descargando archivo 183 de 50000
# Descargado: spec-7820-56984-0749.fits
# Descargando archivo 184 de 50000
# Descargado: spec-1512-53742-0561.fits
# Descargando archivo 185 de 50000
# Descargado: spec-4242-55476-0825.fits
# Descargando archivo 186 de 50000
# Descargado: spec-1512-53742-0568.fits
# Descargando archivo 187 de 50000
# Descargado: spec-7820-56984-0839.fits
# Descargando archivo 188 de 50000
# Descargado: spec-0413-51821-0373.fits
# Descargando archivo 189 de 50000
# Descargado: spec-4242-55476-0868.fits
# Descargando archivo 190 de 50000
# Descargado: spec-0411-51817-0576.fits
# Descargando archivo 191 de 50000
# Descargado: spec-4242-55476-0874.fits
# Descargando archivo 192 de 50000
# Descargado: spec-1565-53002-0331.fits
# Descargando archivo 193 de 50000
# Descargado: spec-7820-56984-0781.fits
# Descargando archivo 194 de 50000
# Descargado: spec-7820-56984-0830.fits
# Descargado: spec-0709-52205-0566.fits
# Descargando archivo 195 de 50000
# Descargando archivo 196 de 50000
# Descargado: spec-7820-56984-0836.fits
# Descargando archivo 197 de 50000
# Descargado: spec-0804-52286-0445.fits
# Descargando archivo 198 de 50000
# Descargado: spec-0804-52286-0373.fits
# Descargado: spec-7820-56984-0838.fits
# Descargado: spec-0414-51869-0325.fits
# Descargando archivo 199 de 50000
# Descargando archivo 200 de 50000
# Descargando archivo 201 de 50000
# Descargado: spec-0413-51821-0615.fits
# Descargando archivo 202 de 50000
# Descargado: spec-1565-53002-0606.fits
# Descargado: spec-0413-51821-0616.fits
# Descargando archivo 203 de 50000
# Descargando archivo 204 de 50000
# Descargado: spec-1064-52577-0333.fits
# Descargando archivo 205 de 50000
# Descargado: spec-0414-51869-0327.fits
# Descargando archivo 206 de 50000
# Descargado: spec-1566-53003-0328.fits
# Descargando archivo 207 de 50000
# Descargado: spec-0712-52199-0412.fits
# Descargando archivo 208 de 50000
# Descargado: spec-1064-52577-0325.fits
# Descargando archivo 209 de 50000
# Descargado: spec-0712-52199-0416.fits
# Descargando archivo 210 de 50000
# Descargado: spec-0712-52199-0415.fits
# Descargando archivo 211 de 50000
# Descargado: spec-0712-52199-0413.fits
# Descargando archivo 212 de 50000
# Descargado: spec-0809-52647-0620.fits
# Descargando archivo 213 de 50000
# Descargado: spec-0809-52647-0614.fits
# Descargando archivo 214 de 50000
# Descargado: spec-0712-52199-0403.fits
# Descargando archivo 215 de 50000
# Descargado: spec-0809-52647-0616.fits
# Descargando archivo 216 de 50000
# Descargado: spec-1566-53003-0330.fits
# Descargando archivo 217 de 50000
# Descargado: spec-0712-52199-0532.fits
# Descargando archivo 218 de 50000
# Descargado: spec-0415-51810-0375.fits
# Descargando archivo 219 de 50000
# Descargado: spec-0415-51810-0401.fits
# Descargando archivo 220 de 50000
# Descargado: spec-0714-52201-0366.fits
# Descargando archivo 221 de 50000
# Descargado: spec-0713-52178-0407.fits
# Descargando archivo 222 de 50000
# Descargado: spec-0416-51811-0418.fits
# Descargando archivo 223 de 50000
# Descargado: spec-0806-52592-0434.fits
# Descargando archivo 224 de 50000
# Descargado: spec-1157-52643-0369.fits
# Descargando archivo 225 de 50000
# Descargado: spec-1157-52643-0379.fits
# Descargando archivo 226 de 50000
# Descargado: spec-0416-51811-0403.fits
# Descargando archivo 227 de 50000
# Descargado: spec-0416-51811-0413.fits
# Descargando archivo 228 de 50000
# Descargado: spec-2638-54095-0377.fits
# Descargado: spec-2638-54095-0375.fits
# Descargando archivo 229 de 50000
# Descargando archivo 230 de 50000
# Descargado: spec-0416-51811-0412.fits
# Descargando archivo 231 de 50000
# Descargado: spec-1632-52996-0407.fits
# Descargando archivo 232 de 50000
# Descargado: spec-1518-52937-0375.fits
# Descargando archivo 233 de 50000
# Descargado: spec-0714-52201-0413.fits
# Descargando archivo 234 de 50000
# Descargado: spec-1062-52619-0374.fits
# Descargando archivo 235 de 50000
# Descargado: spec-1632-52996-0367.fits
# Descargando archivo 236 de 50000
# Descargado: spec-2638-54095-0372.fits
# Descargando archivo 237 de 50000
# Descargado: spec-2640-54806-0366.fits
# Descargando archivo 238 de 50000
# Descargado: spec-1157-52643-0371.fits
# Descargado: spec-2638-54095-0370.fits
# Descargado: spec-1632-52996-0418.fits
# Descargando archivo 239 de 50000
# Descargando archivo 240 de 50000
# Descargando archivo 241 de 50000
# Descargado: spec-2639-54116-0405.fits
# Descargando archivo 242 de 50000
# Descargado: spec-0416-51811-0415.fits
# Descargando archivo 243 de 50000
# Descargado: spec-1632-52996-0413.fits
# Descargando archivo 244 de 50000
# Descargado: spec-1157-52643-0408.fits
# Descargando archivo 245 de 50000
# Descargado: spec-0714-52201-0418.fits
# Descargando archivo 246 de 50000
# Descargado: spec-1157-52643-0418.fits
# Descargado: spec-2639-54116-0415.fits
# Descargando archivo 247 de 50000
# Descargando archivo 248 de 50000
# Descargado: spec-1632-52996-0420.fits
# Descargando archivo 249 de 50000
# Descargado: spec-1157-52643-0417.fits
# Descargando archivo 250 de 50000
# Descargado: spec-0714-52201-0442.fits
# Descargando archivo 251 de 50000
# Descargado: spec-2640-54806-0379.fits
# Descargando archivo 252 de 50000
# Descargado: spec-2638-54095-0414.fits
# Descargando archivo 253 de 50000
# Descargado: spec-1518-52937-0418.fits
# Descargando archivo 254 de 50000
# Descargado: spec-1157-52643-0409.fits
# Descargando archivo 255 de 50000
# Descargado: spec-2638-54095-0406.fits
# Descargando archivo 256 de 50000
# Descargado: spec-0416-51811-0452.fits
# Descargando archivo 257 de 50000
# Descargado: spec-2638-54095-0416.fits
# Descargando archivo 258 de 50000
# Descargado: spec-1632-52996-0419.fits
# Descargando archivo 259 de 50000
# Descargado: spec-2638-54095-0403.fits
# Descargando archivo 260 de 50000
# Descargado: spec-1157-52643-0402.fits
# Descargando archivo 261 de 50000
# Descargado: spec-2638-54095-0419.fits
# Descargando archivo 262 de 50000
# Descargado: spec-2638-54095-0407.fits
# Descargando archivo 263 de 50000
# Descargado: spec-0416-51811-0455.fits
# Descargando archivo 264 de 50000
# Descargado: spec-0416-51811-0453.fits
# Descargando archivo 265 de 50000
# Descargado: spec-1518-52937-0445.fits
# Descargando archivo 266 de 50000
# Descargado: spec-0714-52201-0451.fits
# Descargando archivo 267 de 50000
# Descargado: spec-2639-54116-0443.fits
# Descargando archivo 268 de 50000
# Descargado: spec-1518-52937-0446.fits
# Descargando archivo 269 de 50000
# Descargado: spec-1518-52937-0455.fits
# Descargando archivo 270 de 50000
# Descargado: spec-1062-52619-0363.fits
# Descargando archivo 271 de 50000
# Descargado: spec-2639-54465-0418.fits
# Descargando archivo 272 de 50000
# Descargado: spec-2639-54116-0458.fits
# Descargando archivo 273 de 50000
# Descargado: spec-0416-51811-0445.fits
# Descargando archivo 274 de 50000
# Descargado: spec-2638-54095-0453.fits
# Descargando archivo 275 de 50000
# Descargado: spec-2638-54095-0401.fits
# Descargando archivo 276 de 50000
# Descargado: spec-1062-52619-0420.fits
# Descargando archivo 277 de 50000
# Descargado: spec-1157-52643-0442.fits
# Descargando archivo 278 de 50000
# Descargado: spec-0416-51811-0449.fits
# Descargando archivo 279 de 50000
# Descargado: spec-2639-54116-0444.fits
# Descargando archivo 280 de 50000
# Descargado: spec-1157-52643-0453.fits
# Descargando archivo 281 de 50000
# Descargado: spec-0714-52201-0444.fits
# Descargando archivo 282 de 50000
# Descargado: spec-1632-52996-0441.fits
# Descargando archivo 283 de 50000
# Descargado: spec-1632-52996-0443.fits
# Descargando archivo 284 de 50000
# Descargado: spec-0714-52201-0441.fits
# Descargando archivo 285 de 50000
# Descargado: spec-1518-52937-0458.fits
# Descargando archivo 286 de 50000
# Descargado: spec-1062-52619-0402.fits
# Descargando archivo 287 de 50000
# Descargado: spec-2639-54116-0401.fits
# Descargando archivo 288 de 50000
# Descargado: spec-1062-52619-0406.fits
# Descargado: spec-2639-54116-0447.fits
# Descargando archivo 289 de 50000
# Descargado: spec-1062-52619-0405.fits
# Descargando archivo 290 de 50000
# Descargando archivo 291 de 50000
# Descargado: spec-1632-52996-0539.fits
# Descargando archivo 292 de 50000
# Descargado: spec-2638-54095-0410.fits
# Descargando archivo 293 de 50000
# Descargado: spec-2640-54806-0448.fits
# Descargando archivo 294 de 50000
# Descargado: spec-2638-54095-0455.fits
# Descargando archivo 295 de 50000
# Descargado: spec-2640-54806-0441.fits
# Descargando archivo 296 de 50000
# Descargado: spec-1518-52937-0537.fits
# Descargando archivo 297 de 50000
# Descargado: spec-2640-54806-0455.fits
# Descargando archivo 298 de 50000
# Descargado: spec-1157-52643-0457.fits
# Descargando archivo 299 de 50000
# Descargado: spec-0416-51811-0525.fits
# Descargando archivo 300 de 50000
# Descargado: spec-1157-52643-0459.fits
# Descargando archivo 301 de 50000
# Descargado: spec-3156-54792-0550.fits
# Descargando archivo 302 de 50000
# Descargado: spec-2640-54806-0452.fits
# Descargando archivo 303 de 50000
# Descargado: spec-0416-51811-0533.fits
# Descargando archivo 304 de 50000
# Descargado: spec-1062-52619-0368.fits
# Descargando archivo 305 de 50000
# Descargado: spec-1632-52996-0534.fits
# Descargando archivo 306 de 50000
# Descargado: spec-1632-52996-0524.fits
# Descargando archivo 307 de 50000
# Descargado: spec-1632-52996-0459.fits
# Descargando archivo 308 de 50000
# Descargado: spec-0714-52201-0539.fits
# Descargando archivo 309 de 50000
# Descargado: spec-2639-54116-0540.fits
# Descargando archivo 310 de 50000
# Descargado: spec-1632-52996-0526.fits
# Descargando archivo 311 de 50000
# Descargado: spec-1632-52996-0525.fits
# Descargando archivo 312 de 50000
# Descargado: spec-1062-52619-0404.fits
# Descargando archivo 313 de 50000
# Descargado: spec-2638-54095-0441.fits
# Descargando archivo 314 de 50000
# Descargado: spec-1632-52996-0533.fits
# Descargando archivo 315 de 50000
# Descargado: spec-2638-54095-0444.fits
# Descargando archivo 316 de 50000
# Descargado: spec-0416-51811-0523.fits
# Descargando archivo 317 de 50000
# Descargado: spec-0416-51811-0521.fits
# Descargando archivo 318 de 50000
# Descargado: spec-0714-52201-0530.fits
# Descargando archivo 319 de 50000
# Descargado: spec-1157-52643-0450.fits
# Descargando archivo 320 de 50000
# Descargado: spec-1632-52996-0530.fits
# Descargando archivo 321 de 50000
# Descargado: spec-1157-52643-0527.fits
# Descargando archivo 322 de 50000
# Descargado: spec-1062-52619-0411.fits
# Descargando archivo 323 de 50000
# Descargado: spec-2638-54095-0539.fits
# Descargando archivo 324 de 50000
# Descargado: spec-1062-52619-0444.fits
# Descargando archivo 325 de 50000
# Descargado: spec-0714-52201-0525.fits
# Descargando archivo 326 de 50000
# Descargado: spec-1632-52996-0527.fits
# Descargado: spec-1062-52619-0459.fits
# Descargando archivo 327 de 50000
# Descargando archivo 328 de 50000
# Descargado: spec-0416-51811-0527.fits
# Descargando archivo 329 de 50000
# Descargado: spec-1157-52643-0528.fits
# Descargando archivo 330 de 50000
# Descargado: spec-1157-52643-0531.fits
# Descargando archivo 331 de 50000
# Descargado: spec-0714-52201-0523.fits
# Descargando archivo 332 de 50000
# Descargado: spec-1157-52643-0535.fits
# Descargando archivo 333 de 50000
# Descargado: spec-2639-54116-0571.fits
# Descargado: spec-0416-51811-0567.fits
# Descargando archivo 334 de 50000
# Descargando archivo 335 de 50000
# Descargado: spec-1157-52643-0526.fits
# Descargando archivo 336 de 50000
# Descargado: spec-2638-54095-0442.fits
# Descargando archivo 337 de 50000
# Descargado: spec-1518-52937-0580.fits
# Descargando archivo 338 de 50000
# Descargado: spec-1157-52643-0530.fits
# Descargando archivo 339 de 50000
# Descargado: spec-2639-54116-0536.fits
# Descargando archivo 340 de 50000
# Descargado: spec-0416-51811-0579.fits
# Descargando archivo 341 de 50000
# Descargado: spec-0416-51811-0572.fits
# Descargando archivo 342 de 50000
# Descargado: spec-1157-52643-0533.fits
# Descargando archivo 343 de 50000
# Descargado: spec-1632-52996-0578.fits
# Descargando archivo 344 de 50000
# Descargado: spec-1632-52996-0522.fits
# Descargando archivo 345 de 50000
# Descargado: spec-2639-54465-0562.fits
# Descargando archivo 346 de 50000
# Descargado: spec-1518-52937-0561.fits
# Descargado: spec-2640-54806-0527.fits
# Descargando archivo 347 de 50000
# Descargando archivo 348 de 50000
# Descargado: spec-2638-54095-0529.fits
# Descargando archivo 349 de 50000
# Descargado: spec-2638-54095-0534.fits
# Descargando archivo 350 de 50000
# Descargado: spec-2640-54806-0537.fits
# Descargando archivo 351 de 50000
# Descargado: spec-2639-54465-0522.fits
# Descargado: spec-0714-52201-0572.fits
# Descargando archivo 352 de 50000
# Descargando archivo 353 de 50000
# Descargado: spec-1157-52643-0529.fits
# Descargando archivo 354 de 50000
# Descargado: spec-0714-52201-0576.fits
# Descargando archivo 355 de 50000
# Descargado: spec-0714-52201-0579.fits
# Descargando archivo 356 de 50000
# Descargado: spec-1632-52996-0575.fits
# Descargando archivo 357 de 50000
# Descargado: spec-1632-52996-0579.fits
# Descargando archivo 358 de 50000
# Descargado: spec-2638-54095-0535.fits
# Descargando archivo 359 de 50000
# Descargado: spec-0416-51811-0571.fits
# Descargando archivo 360 de 50000
# Descargado: spec-0416-51811-0574.fits
# Descargando archivo 361 de 50000
# Descargado: spec-0416-51811-0615.fits
# Descargando archivo 362 de 50000
# Descargado: spec-0416-51811-0578.fits
# Descargando archivo 363 de 50000
# Descargado: spec-1157-52643-0568.fits
# Descargando archivo 364 de 50000
# Descargado: spec-0714-52201-0613.fits
# Descargando archivo 365 de 50000
# Descargado: spec-1062-52619-0527.fits
# Descargando archivo 366 de 50000
# Descargado: spec-0416-51811-0566.fits
# Descargando archivo 367 de 50000
# Descargado: spec-0714-52201-0607.fits
# Descargando archivo 368 de 50000
# Descargado: spec-0416-51811-0613.fits
# Descargando archivo 369 de 50000
# Descargado: spec-0416-51811-0577.fits
# Descargando archivo 370 de 50000
# Descargado: spec-1062-52619-0523.fits
# Descargando archivo 371 de 50000
# Descargado: spec-1632-52996-0563.fits
# Descargando archivo 372 de 50000
# Descargado: spec-0714-52201-0611.fits
# Descargando archivo 373 de 50000
# Descargado: spec-2639-54465-0571.fits
# Descargando archivo 374 de 50000
# Descargado: spec-0714-52201-0563.fits
# Descargando archivo 375 de 50000
# Descargado: spec-2638-54095-0569.fits
# Descargando archivo 376 de 50000
# Descargado: spec-1632-52996-0561.fits
# Descargando archivo 377 de 50000
# Descargado: spec-2638-54095-0619.fits
# Descargado: spec-1062-52619-0534.fits
# Descargando archivo 378 de 50000
# Descargando archivo 379 de 50000
# Descargado: spec-2638-54095-0578.fits
# Descargando archivo 380 de 50000
# Descargado: spec-2638-54095-0533.fits
# Descargando archivo 381 de 50000
# Descargado: spec-1157-52643-0562.fits
# Descargando archivo 382 de 50000
# Descargado: spec-1062-52619-0537.fits
# Descargando archivo 383 de 50000
# Descargado: spec-2638-54095-0563.fits
# Descargando archivo 384 de 50000
# Descargado: spec-2638-54095-0571.fits
# Descargando archivo 385 de 50000
# Descargado: spec-2639-54116-0565.fits
# Descargando archivo 386 de 50000
# Descargado: spec-2639-54465-0610.fits
# Descargando archivo 387 de 50000
# Descargado: spec-0416-51811-0564.fits
# Descargando archivo 388 de 50000
# Descargado: spec-2640-54474-0564.fits
# Descargando archivo 389 de 50000
# Descargado: spec-2639-54465-0576.fitsDescargado: spec-2640-54474-0571.fits
#
# Descargando archivo 390 de 50000
# Descargando archivo 391 de 50000
# Descargado: spec-1632-52996-0566.fits
# Descargando archivo 392 de 50000
# Descargado: spec-1632-52996-0568.fits
# Descargando archivo 393 de 50000
# Descargado: spec-2640-54806-0570.fits
# Descargado: spec-2640-54474-0562.fits
# Descargando archivo 394 de 50000
# Descargando archivo 395 de 50000
# Descargado: spec-0714-52201-0610.fits
# Descargando archivo 396 de 50000
# Descargado: spec-0714-52201-0620.fits
# Descargando archivo 397 de 50000
# Descargado: spec-0416-51811-0620.fits
# Descargando archivo 398 de 50000
# Descargado: spec-1062-52619-0575.fits
# Descargando archivo 399 de 50000
# Descargado: spec-0416-51811-0614.fits
# Descargando archivo 400 de 50000
# Descargado: spec-0416-51811-0619.fits
# Descargando archivo 401 de 50000
# Descargado: spec-0416-51811-0604.fits
# Descargando archivo 402 de 50000
# Descargado: spec-0416-51811-0611.fits
# Descargando archivo 403 de 50000
# Descargado: spec-1157-52643-0580.fits
# Descargando archivo 404 de 50000
# Descargado: spec-1632-52996-0612.fits
# Descargando archivo 405 de 50000
# Descargado: spec-1632-52996-0602.fits
# Descargando archivo 406 de 50000
# Descargado: spec-0714-52201-0606.fits
# Descargando archivo 407 de 50000
# Descargado: spec-1157-52643-0579.fits
# Descargando archivo 408 de 50000
# Descargado: spec-1518-52937-0602.fits
# Descargando archivo 409 de 50000
# Descargado: spec-1632-52996-0609.fits
# Descargando archivo 410 de 50000
# Descargado: spec-1632-52996-0570.fits
# Descargando archivo 411 de 50000
# Descargado: spec-2639-54116-0617.fits
# Descargando archivo 412 de 50000
# Descargado: spec-1062-52619-0567.fits
# Descargando archivo 413 de 50000
# Descargado: spec-2638-54095-0618.fits
# Descargando archivo 414 de 50000
# Descargado: spec-1243-52930-0331.fits
# Descargando archivo 415 de 50000
# Descargado: spec-2638-54095-0603.fits
# Descargado: spec-1062-52619-0580.fits
# Descargando archivo 416 de 50000
# Descargando archivo 417 de 50000
# Descargado: spec-2639-54465-0608.fits
# Descargando archivo 418 de 50000
# Descargado: spec-2639-54116-0602.fits
# Descargando archivo 419 de 50000
# Descargado: spec-1062-52619-0563.fits
# Descargando archivo 420 de 50000
# Descargado: spec-0416-51811-0609.fits
# Descargando archivo 421 de 50000
# Descargado: spec-2638-54095-0602.fits
# Descargando archivo 422 de 50000
# Descargado: spec-2640-54474-0604.fits
# Descargando archivo 423 de 50000
# Descargado: spec-0416-51811-0610.fits
# Descargando archivo 424 de 50000
# Descargado: spec-2639-54465-0605.fits
# Descargando archivo 425 de 50000
# Descargado: spec-1157-52643-0603.fits
# Descargando archivo 426 de 50000
# Descargado: spec-2639-54116-0607.fits
# Descargando archivo 427 de 50000
# Descargado: spec-2638-54095-0610.fits
# Descargando archivo 428 de 50000
# Descargado: spec-1062-52619-0614.fits
# Descargando archivo 429 de 50000
# Descargado: spec-1062-52619-0601.fits
# Descargando archivo 430 de 50000
# Descargado: spec-0416-51811-0607.fits
# Descargando archivo 431 de 50000
# Descargado: spec-2638-54095-0604.fits
# Descargado: spec-1157-52643-0605.fits
# Descargando archivo 432 de 50000
# Descargando archivo 433 de 50000
# Descargado: spec-1632-52996-0610.fitsDescargado: spec-2640-54806-0607.fits
#
# Descargando archivo 434 de 50000
# Descargando archivo 435 de 50000
# Descargado: spec-1062-52619-0566.fits
# Descargando archivo 436 de 50000
# Descargado: spec-1632-52996-0604.fits
# Descargando archivo 437 de 50000
# Descargado: spec-1243-52930-0339.fits
# Descargando archivo 438 de 50000
# Descargado: spec-2640-54806-0603.fits
# Descargando archivo 439 de 50000
# Descargado: spec-1632-52996-0613.fits
# Descargando archivo 440 de 50000
# Descargado: spec-1157-52643-0604.fits
# Descargando archivo 441 de 50000
# Descargado: spec-1157-52643-0607.fits
# Descargando archivo 442 de 50000
# Descargado: spec-1632-52996-0620.fits
# Descargando archivo 443 de 50000
# Descargado: spec-1632-52996-0606.fits
# Descargando archivo 444 de 50000
# Descargado: spec-1632-52996-0607.fits
# Descargando archivo 445 de 50000
# Descargado: spec-2638-54095-0608.fits
# Descargando archivo 446 de 50000
# Descargado: spec-0416-51811-0605.fits
# Descargando archivo 447 de 50000
# Descargado: spec-1062-52619-0609.fits
# Descargando archivo 448 de 50000
# Descargado: spec-2638-54095-0614.fits
# Descargando archivo 449 de 50000
# Descargado: spec-1157-52643-0614.fits
# Descargando archivo 450 de 50000
# Descargado: spec-1633-52998-0328.fits
# Descargando archivo 451 de 50000
# Descargado: spec-1632-52996-0601.fits
# Descargando archivo 452 de 50000
# Descargado: spec-2639-54116-0608.fits
# Descargando archivo 453 de 50000
# Descargado: spec-1633-52998-0323.fits
# Descargando archivo 454 de 50000
# Descargado: spec-2640-54806-0605.fits
# Descargando archivo 455 de 50000
# Descargado: spec-1529-52930-0350.fits
# Descargando archivo 456 de 50000
# Descargado: spec-1242-52901-0324.fits
# Descargando archivo 457 de 50000
# Descargado: spec-1632-52996-0608.fits
# Descargando archivo 458 de 50000
# Descargado: spec-1242-52901-0334.fits
# Descargando archivo 459 de 50000
# Descargado: spec-1243-52930-0334.fits
# Descargando archivo 460 de 50000
# Descargado: spec-1633-52998-0373.fits
# Descargando archivo 461 de 50000
# Descargado: spec-1529-52930-0352.fits
# Descargado: spec-1243-52930-0338.fits
# Descargando archivo 462 de 50000
# Descargando archivo 463 de 50000
# Descargado: spec-1529-52930-0349.fits
# Descargando archivo 464 de 50000
# Descargado: spec-1157-52643-0617.fits
# Descargando archivo 465 de 50000
# Descargado: spec-1633-52998-0372.fits
# Descargado: spec-1243-52930-0327.fits
# Descargando archivo 466 de 50000
# Descargando archivo 467 de 50000
# Descargado: spec-1633-52998-0362.fits
# Descargando archivo 468 de 50000
# Descargado: spec-1243-52930-0328.fits
# Descargando archivo 469 de 50000
# Descargado: spec-1633-52998-0380.fits
# Descargando archivo 470 de 50000
# Descargado: spec-1242-52901-0333.fits
# Descargando archivo 471 de 50000
# Descargado: spec-1242-52901-0331.fits
# Descargando archivo 472 de 50000
# Descargado: spec-1529-52930-0391.fits
# Descargando archivo 473 de 50000
# Descargado: spec-1242-52901-0335.fits
# Descargando archivo 474 de 50000
# Descargado: spec-1529-52930-0390.fits
# Descargando archivo 475 de 50000
# Descargado: spec-1529-52930-0385.fits
# Descargando archivo 476 de 50000
# Descargado: spec-1529-52930-0392.fits
# Descargando archivo 477 de 50000
# Descargado: spec-1242-52901-0374.fits
# Descargando archivo 478 de 50000
# Descargado: spec-1243-52930-0367.fits
# Descargando archivo 479 de 50000
# Descargado: spec-1633-52998-0420.fits
# Descargando archivo 480 de 50000
# Descargado: spec-1243-52930-0371.fits
# Descargando archivo 481 de 50000
# Descargado: spec-1243-52930-0323.fits
# Descargando archivo 482 de 50000
# Descargado: spec-1243-52930-0372.fits
# Descargando archivo 483 de 50000
# Descargado: spec-1633-52998-0364.fits
# Descargando archivo 484 de 50000
# Descargado: spec-1243-52930-0325.fits
# Descargando archivo 485 de 50000
# Descargado: spec-1243-52930-0374.fits
# Descargando archivo 486 de 50000
# Descargado: spec-1243-52930-0362.fits
# Descargando archivo 487 de 50000
# Descargado: spec-1633-52998-0402.fits
# Descargando archivo 488 de 50000
# Descargado: spec-1242-52901-0375.fits
# Descargando archivo 489 de 50000
# Descargado: spec-1529-52930-0393.fits
# Descargando archivo 490 de 50000
# Descargado: spec-1242-52901-0373.fits
# Descargando archivo 491 de 50000
# Descargado: spec-1243-52930-0378.fits
# Descargando archivo 492 de 50000
# Descargado: spec-1243-52930-0411.fits
# Descargando archivo 493 de 50000
# Descargado: spec-1633-52998-0406.fits
# Descargando archivo 494 de 50000
# Descargado: spec-1633-52998-0408.fits
# Descargando archivo 495 de 50000
# Descargado: spec-1633-52998-0419.fits
# Descargando archivo 496 de 50000
# Descargado: spec-1529-52930-0383.fits
# Descargando archivo 497 de 50000
# Descargado: spec-1633-52998-0410.fits
# Descargando archivo 498 de 50000
# Descargado: spec-1243-52930-0375.fits
# Descargando archivo 499 de 50000
# Descargado: spec-1633-52998-0411.fits
# Descargando archivo 500 de 50000
# Descargado: spec-1633-52998-0417.fits
# Descargando archivo 501 de 50000
# Descargado: spec-1243-52930-0370.fits
# Descargando archivo 502 de 50000
# Descargado: spec-1243-52930-0416.fits
# Descargando archivo 503 de 50000
# Descargado: spec-1633-52998-0413.fits
# Descargando archivo 504 de 50000
# Descargado: spec-1529-52930-0428.fits
# Descargando archivo 505 de 50000
# Descargado: spec-1242-52901-0364.fits
# Descargando archivo 506 de 50000
# Descargado: spec-1243-52930-0407.fits
# Descargado: spec-1243-52930-0403.fits
# Descargando archivo 507 de 50000
# Descargando archivo 508 de 50000
# Descargado: spec-1242-52901-0407.fits
# Descargando archivo 509 de 50000
# Descargado: spec-1529-52930-0433.fits
# Descargando archivo 510 de 50000
# Descargado: spec-1243-52930-0420.fits
# Descargando archivo 511 de 50000
# Descargado: spec-1242-52901-0372.fits
# Descargando archivo 512 de 50000
# Descargado: spec-1243-52930-0406.fits
# Descargando archivo 513 de 50000
# Descargado: spec-1243-52930-0413.fits
# Descargando archivo 514 de 50000
# Descargado: spec-1633-52998-0452.fits
# Descargando archivo 515 de 50000
# Descargado: spec-1633-52998-0405.fits
# Descargando archivo 516 de 50000
# Descargado: spec-1242-52901-0403.fits
# Descargando archivo 517 de 50000
# Descargado: spec-1242-52901-0409.fits
# Descargando archivo 518 de 50000
# Descargado: spec-1633-52998-0448.fits
# Descargando archivo 519 de 50000
# Descargado: spec-1243-52930-0409.fits
# Descargando archivo 520 de 50000
# Descargado: spec-1242-52901-0416.fits
# Descargando archivo 521 de 50000
# Descargado: spec-1242-52901-0402.fits
# Descargando archivo 522 de 50000
# Descargado: spec-1243-52930-0414.fits
# Descargando archivo 523 de 50000
# Descargado: spec-1243-52930-0402.fits
# Descargando archivo 524 de 50000
# Descargado: spec-1529-52930-0439.fits
# Descargando archivo 525 de 50000
# Descargado: spec-1633-52998-0449.fits
# Descargando archivo 526 de 50000
# Descargado: spec-1242-52901-0420.fits
# Descargando archivo 527 de 50000
# Descargado: spec-1633-52998-0455.fits
# Descargando archivo 528 de 50000
# Descargado: spec-1243-52930-0454.fits
# Descargado: spec-1529-52930-0431.fits
# Descargando archivo 529 de 50000
# Descargando archivo 530 de 50000
# Descargado: spec-1243-52930-0456.fits
# Descargando archivo 531 de 50000
# Descargado: spec-1242-52901-0452.fits
# Descargando archivo 532 de 50000
# Descargado: spec-1633-52998-0441.fits
# Descargando archivo 533 de 50000
# Descargado: spec-1243-52930-0460.fits
# Descargando archivo 534 de 50000
# Descargado: spec-1529-52930-0507.fits
# Descargando archivo 535 de 50000
# Descargado: spec-1242-52901-0449.fits
# Descargando archivo 536 de 50000
# Descargado: spec-1633-52998-0442.fits
# Descargando archivo 537 de 50000
# Descargado: spec-1529-52930-0513.fits
# Descargando archivo 538 de 50000
# Descargado: spec-1242-52901-0445.fits
# Descargando archivo 539 de 50000
# Descargado: spec-1242-52901-0444.fits
# Descargando archivo 540 de 50000
# Descargado: spec-1242-52901-0442.fits
# Descargando archivo 541 de 50000
# Descargado: spec-1242-52901-0458.fits
# Descargando archivo 542 de 50000
# Descargado: spec-1242-52901-0459.fits
# Descargando archivo 543 de 50000
# Descargado: spec-1633-52998-0528.fits
# Descargando archivo 544 de 50000
# Descargado: spec-1243-52930-0455.fits
# Descargando archivo 545 de 50000
# Descargado: spec-1633-52998-0534.fits
# Descargando archivo 546 de 50000
# Descargado: spec-1633-52998-0523.fits
# Descargando archivo 547 de 50000
# Descargado: spec-1529-52930-0512.fits
# Descargando archivo 548 de 50000
# Descargado: spec-1633-52998-0529.fits
# Descargando archivo 549 de 50000
# Descargado: spec-1242-52901-0525.fits
# Descargando archivo 550 de 50000
# Descargado: spec-1633-52998-0535.fits
# Descargando archivo 551 de 50000
# Descargado: spec-1633-52998-0540.fits
# Descargando archivo 552 de 50000
# Descargado: spec-1242-52901-0526.fits
# Descargando archivo 553 de 50000
# Descargado: spec-1529-52930-0545.fits
# Descargando archivo 554 de 50000
# Descargado: spec-1242-52901-0533.fits
# Descargando archivo 555 de 50000
# Descargado: spec-1242-52901-0527.fits
# Descargando archivo 556 de 50000
# Descargado: spec-1242-52901-0539.fits
# Descargando archivo 557 de 50000
# Descargado: spec-1633-52998-0577.fits
# Descargando archivo 558 de 50000
# Descargado: spec-1633-52998-0527.fits
# Descargando archivo 559 de 50000
# Descargado: spec-1243-52930-0448.fits
# Descargando archivo 560 de 50000
# Descargado: spec-1633-52998-0536.fits
# Descargando archivo 561 de 50000
# Descargado: spec-1243-52930-0535.fits
# Descargando archivo 562 de 50000
# Descargado: spec-1242-52901-0535.fits
# Descargando archivo 563 de 50000
# Descargado: spec-1529-52930-0556.fits
# Descargando archivo 564 de 50000
# Descargado: spec-1633-52998-0576.fits
# Descargando archivo 565 de 50000
# Descargado: spec-1242-52901-0563.fits
# Descargando archivo 566 de 50000
# Descargado: spec-1243-52930-0527.fits
# Descargando archivo 567 de 50000
# Descargado: spec-1243-52930-0523.fits
# Descargando archivo 568 de 50000
# Descargado: spec-1242-52901-0522.fits
# Descargando archivo 569 de 50000
# Descargado: spec-1243-52930-0525.fits
# Descargando archivo 570 de 50000
# Descargado: spec-1529-52930-0595.fits
# Descargando archivo 571 de 50000
# Descargado: spec-1529-52930-0550.fits
# Descargando archivo 572 de 50000
# Descargado: spec-1633-52998-0562.fits
# Descargando archivo 573 de 50000
# Descargado: spec-1242-52901-0578.fits
# Descargando archivo 574 de 50000
# Descargado: spec-1529-52930-0588.fits
# Descargando archivo 575 de 50000
# Descargado: spec-1633-52998-0570.fits
# Descargando archivo 576 de 50000
# Descargado: spec-1529-52930-0598.fits
# Descargando archivo 577 de 50000
# Descargado: spec-1243-52930-0522.fits
# Descargado: spec-1633-52998-0561.fits
# Descargando archivo 578 de 50000
# Descargando archivo 579 de 50000
# Descargado: spec-1243-52930-0571.fits
# Descargando archivo 580 de 50000
# Descargado: spec-1529-52930-0594.fits
# Descargando archivo 581 de 50000
# Descargado: spec-1529-52930-0590.fits
# Descargando archivo 582 de 50000
# Descargado: spec-1242-52901-0614.fits
# Descargando archivo 583 de 50000
# Descargado: spec-1529-52930-0591.fits
# Descargando archivo 584 de 50000
# Descargado: spec-1243-52930-0578.fits
# Descargando archivo 585 de 50000
# Descargado: spec-1243-52930-0580.fits
# Descargando archivo 586 de 50000
# Descargado: spec-1243-52930-0563.fits
# Descargando archivo 587 de 50000
# Descargado: spec-1243-52930-0575.fits
# Descargando archivo 588 de 50000
# Descargado: spec-1243-52930-0579.fits
# Descargando archivo 589 de 50000
# Descargado: spec-1633-52998-0609.fits
# Descargando archivo 590 de 50000
# Descargado: spec-1633-52998-0619.fits
# Descargado: spec-1243-52930-0576.fits
# Descargado: spec-1243-52930-0613.fits
# Descargando archivo 591 de 50000
# Descargando archivo 592 de 50000
# Descargando archivo 593 de 50000
# Descargado: spec-1633-52998-0610.fits
# Descargando archivo 594 de 50000
# Descargado: spec-1633-52998-0611.fits
# Descargando archivo 595 de 50000
# Descargado: spec-1242-52901-0610.fits
# Descargando archivo 596 de 50000
# Descargado: spec-1633-52998-0617.fits
# Descargando archivo 597 de 50000
# Descargado: spec-1243-52930-0602.fits
# Descargando archivo 598 de 50000
# Descargado: spec-1243-52930-0610.fits
# Descargando archivo 599 de 50000
# Descargado: spec-1243-52930-0603.fits
# Descargando archivo 600 de 50000
# Descargado: spec-1242-52901-0615.fits
# Descargando archivo 601 de 50000
# Descargado: spec-1529-52930-0637.fits
# Descargando archivo 602 de 50000
# Descargado: spec-1243-52930-0606.fits
# Descargando archivo 603 de 50000
# Descargado: spec-1243-52930-0609.fits
# Descargando archivo 604 de 50000
# Descargado: spec-1633-52998-0620.fits
# Descargando archivo 605 de 50000
# Descargado: spec-1633-52998-0606.fits
# Descargando archivo 606 de 50000
# Descargado: spec-1529-52930-0624.fits
# Descargando archivo 607 de 50000
# Descargado: spec-1242-52901-0602.fits
# Descargando archivo 608 de 50000
# Descargado: spec-1243-52930-0608.fits
# Descargando archivo 609 de 50000
# Descargado: spec-1243-52930-0612.fits
# Descargando archivo 610 de 50000
# Descargado: spec-1242-52901-0601.fits
# Descargando archivo 611 de 50000
# Descargado: spec-1242-52901-0613.fits
# Descargando archivo 612 de 50000
# Descargado: spec-1633-52998-0601.fits
# Descargado: spec-1242-52901-0603.fits
# Descargando archivo 613 de 50000
# Descargando archivo 614 de 50000
# Descargado: spec-1243-52930-0604.fits
# Descargando archivo 615 de 50000
# Descargado: spec-1633-52998-0639.fits
# Descargando archivo 616 de 50000
# Descargado: spec-1243-52930-0601.fits
# Descargando archivo 617 de 50000
# Descargado: spec-1529-52930-0628.fits
# Descargando archivo 618 de 50000
# Descargado: spec-1249-54484-0282.fits
# Descargando archivo 619 de 50000
# Descargado: spec-0414-51869-0606.fits
# Descargando archivo 620 de 50000
# Descargado: spec-0711-52202-0450.fits
# Descargando archivo 621 de 50000
# Descargado: spec-1246-53783-0146.fits
# Descargando archivo 622 de 50000
# Descargado: spec-1246-53783-0016.fits
# Descargando archivo 623 de 50000
# Descargado: spec-0415-51810-0521.fits
# Descargando archivo 624 de 50000
# Descargado: spec-1246-54478-0018.fits
# Descargando archivo 625 de 50000
# Descargado: spec-0797-52263-0024.fits
# Descargando archivo 626 de 50000
# Descargado: spec-1247-52677-0222.fits
# Descargando archivo 627 de 50000
# Descargado: spec-1247-52677-0259.fits
# Descargando archivo 628 de 50000
# Descargado: spec-7821-57279-0212.fits
# Descargando archivo 629 de 50000
# Descargado: spec-1246-54478-0033.fits
# Descargando archivo 630 de 50000
# Descargado: spec-1247-52677-0173.fits
# Descargando archivo 631 de 50000
# Descargado: spec-0797-52263-0022.fits
# Descargando archivo 632 de 50000
# Descargado: spec-0797-52263-0431.fits
# Descargando archivo 633 de 50000
# Descargado: spec-0797-52263-0498.fits
# Descargando archivo 634 de 50000
# Descargado: spec-0797-52263-0271.fits
# Descargando archivo 635 de 50000
# Descargado: spec-0797-52263-0475.fits
# Descargando archivo 636 de 50000
# Descargado: spec-0797-52263-0520.fits
# Descargando archivo 637 de 50000
# Descargado: spec-0797-52263-0440.fits
# Descargando archivo 638 de 50000
# Descargado: spec-0797-52263-0621.fits
# Descargando archivo 639 de 50000
# Descargado: spec-0797-52263-0195.fits
# Descargando archivo 640 de 50000
# Descargado: spec-0797-52263-0492.fits
# Descargando archivo 641 de 50000
# Descargado: spec-0797-52263-0075.fits
# Descargado: spec-7257-56658-0097.fits
# Descargando archivo 642 de 50000
# Descargando archivo 643 de 50000
# Descargado: spec-7257-56658-0214.fits
# Descargando archivo 644 de 50000
# Descargado: spec-7257-56658-0049.fits
# Descargando archivo 645 de 50000
# Descargado: spec-2072-53430-0312.fits
# Descargando archivo 646 de 50000
# Descargado: spec-7257-56658-0045.fits
# Descargando archivo 647 de 50000
# Descargado: spec-7257-56658-0380.fits
# Descargando archivo 648 de 50000
# Descargado: spec-0797-52263-0360.fits
# Descargando archivo 649 de 50000
# Descargado: spec-1248-54477-0118.fits
# Descargando archivo 650 de 50000
# Descargado: spec-0797-52263-0469.fits
# Descargando archivo 651 de 50000
# Descargado: spec-0797-52263-0381.fits
# Descargando archivo 652 de 50000
# Descargado: spec-7257-56658-0350.fits
# Descargando archivo 653 de 50000
# Descargado: spec-7257-56658-0300.fits
# Descargando archivo 654 de 50000
# Descargado: spec-0797-52263-0490.fits
# Descargando archivo 655 de 50000
# Descargado: spec-7257-56658-0394.fits
# Descargando archivo 656 de 50000
# Descargado: spec-7257-56658-0378.fits
# Descargando archivo 657 de 50000
# Descargado: spec-0797-52263-0510.fits
# Descargando archivo 658 de 50000
# Descargado: spec-0797-52263-0628.fits
# Descargado: spec-0797-52263-0516.fits
# Descargando archivo 659 de 50000
# Descargado: spec-0797-52263-0393.fits
# Descargando archivo 660 de 50000
# Descargando archivo 661 de 50000
# Descargado: spec-0797-52263-0472.fits
# Descargando archivo 662 de 50000
# Descargado: spec-7257-56658-0345.fits
# Descargando archivo 663 de 50000
# Descargado: spec-7257-56658-0349.fits
# Descargado: spec-0797-52263-0545.fits
# Descargando archivo 664 de 50000
# Descargando archivo 665 de 50000
# Descargado: spec-7257-56658-0104.fits
# Descargando archivo 666 de 50000
# Descargado: spec-7257-56658-0183.fits
# Descargando archivo 667 de 50000
# Descargado: spec-7257-56658-0271.fits
# Descargando archivo 668 de 50000
# Descargado: spec-7257-56658-0191.fits
# Descargado: spec-7257-56658-0102.fits
# Descargando archivo 669 de 50000
# Descargando archivo 670 de 50000
# Descargado: spec-7257-56658-0110.fits
# Descargando archivo 671 de 50000
# Descargado: spec-7257-56658-0003.fits
# Descargando archivo 672 de 50000
# Descargado: spec-1244-52674-0485.fits
# Descargando archivo 673 de 50000
# Descargado: spec-7257-56658-0579.fits
# Descargando archivo 674 de 50000
# Descargado: spec-7257-56658-0515.fits
# Descargando archivo 675 de 50000
# Descargado: spec-7257-56658-0539.fits
# Descargando archivo 676 de 50000
# Descargado: spec-7261-56603-0164.fits
# Descargando archivo 677 de 50000
# Descargado: spec-7261-56603-0286.fits
# ...
# Descargado: spec-4661-55614-0820.fits
# Descargando archivo 49783 de 50000
# Descargado: spec-11060-58523-0103.fits
# Descargando archivo 49784 de 50000
# Descargado: spec-4661-55614-0855.fits
# Descargado: spec-11060-58523-0184.fits
# Descargando archivo 49785 de 50000
# Descargando archivo 49786 de 50000
# Descargado: spec-0426-51882-0200.fits
# Descargando archivo 49787 de 50000
# Descargado: spec-4661-55614-0819.fits
# Descargando archivo 49788 de 50000
# Descargado: spec-0426-51882-0195.fits
# Descargando archivo 49789 de 50000
# Descargado: spec-11060-58523-0153.fits
# Descargando archivo 49790 de 50000
# Descargado: spec-4661-55614-0854.fits
# Descargando archivo 49791 de 50000
# Descargado: spec-4661-55614-0852.fits
# Descargando archivo 49792 de 50000
# Descargado: spec-0426-51882-0192.fits
# Descargando archivo 49793 de 50000
# Descargado: spec-11060-58523-0108.fits
# Descargando archivo 49794 de 50000
# Descargado: spec-0426-51882-0176.fits
# Descargando archivo 49795 de 50000
# Descargado: spec-0426-51882-0174.fits
# Descargando archivo 49796 de 50000
# Descargado: spec-0426-51882-0167.fits
# Descargando archivo 49797 de 50000
# Descargado: spec-0426-51882-0166.fits
# Descargando archivo 49798 de 50000
# Descargado: spec-11060-58523-0151.fits
# Descargando archivo 49799 de 50000
# Descargado: spec-0426-51882-0229.fits
# Descargando archivo 49800 de 50000
# Descargado: spec-0426-51882-0171.fits
# Descargando archivo 49801 de 50000
# Descargado: spec-0426-51882-0172.fits
# Descargando archivo 49802 de 50000
# Descargado: spec-11060-58523-0149.fits
# Descargando archivo 49803 de 50000
# Descargado: spec-11060-58523-0105.fits
# Descargando archivo 49804 de 50000
# Descargado: spec-11060-58523-0114.fits
# Descargando archivo 49805 de 50000
# Descargado: spec-0426-51882-0144.fits
# Descargando archivo 49806 de 50000
# Descargado: spec-0426-51882-0153.fits
# Descargando archivo 49807 de 50000
# Descargado: spec-0426-51882-0147.fits
# Descargando archivo 49808 de 50000
# Descargado: spec-4661-55614-0768.fits
# Descargando archivo 49809 de 50000
# Descargado: spec-11060-58523-0106.fits
# Descargando archivo 49810 de 50000
# Descargado: spec-4661-55614-0900.fits
# Descargando archivo 49811 de 50000
# Descargado: spec-0426-51882-0160.fits
# Descargando archivo 49812 de 50000
# Descargado: spec-0426-51882-0159.fits
# Descargando archivo 49813 de 50000
# Descargado: spec-4661-55614-0899.fits
# Descargando archivo 49814 de 50000
# Descargado: spec-4661-55614-0892.fits
# Descargando archivo 49815 de 50000
# Descargado: spec-4661-55614-0898.fits
# Descargando archivo 49816 de 50000
# Descargado: spec-4661-55614-0933.fits
# Descargando archivo 49817 de 50000
# Descargado: spec-11060-58523-0102.fits
# Descargando archivo 49818 de 50000
# Descargado: spec-4661-55614-0897.fits
# Descargando archivo 49819 de 50000
# Descargado: spec-0426-51882-0157.fits
# Descargando archivo 49820 de 50000
# Descargado: spec-0426-51882-0152.fits
# Descargando archivo 49821 de 50000
# Descargado: spec-11060-58523-0067.fits
# Descargando archivo 49822 de 50000
# Descargado: spec-0426-51882-0113.fits
# Descargando archivo 49823 de 50000
# Descargado: spec-11060-58523-0069.fits
# Descargando archivo 49824 de 50000
# Descargado: spec-11060-58523-0065.fits
# Descargando archivo 49825 de 50000
# Descargado: spec-0426-51882-0119.fits
# Descargando archivo 49826 de 50000
# Descargado: spec-11060-58523-0064.fits
# Descargado: spec-0426-51882-0108.fits
# Descargando archivo 49827 de 50000
# Descargando archivo 49828 de 50000
# Descargado: spec-0426-51882-0120.fits
# Descargando archivo 49829 de 50000
# Descargado: spec-11060-58523-0063.fits
# Descargando archivo 49830 de 50000
# Descargado: spec-4661-55614-0934.fits
# Descargando archivo 49831 de 50000
# Descargado: spec-4661-55614-0939.fits
# Descargando archivo 49832 de 50000
# Descargado: spec-4661-55614-0937.fits
# Descargando archivo 49833 de 50000
# Descargado: spec-11060-58523-0026.fits
# Descargado: spec-4658-55592-0499.fits
# Descargando archivo 49834 de 50000
# Descargando archivo 49835 de 50000
# Descargado: spec-4661-55614-0935.fits
# Descargando archivo 49836 de 50000
# Descargado: spec-4658-55592-0517.fits
# Descargando archivo 49837 de 50000
# Descargado: spec-4658-55592-0519.fits
# Descargando archivo 49838 de 50000
# Descargado: spec-0426-51882-0117.fits
# Descargado: spec-4658-55592-0520.fits
# Descargando archivo 49839 de 50000
# Descargando archivo 49840 de 50000
# Descargado: spec-4661-55614-0940.fits
# Descargando archivo 49841 de 50000
# Descargado: spec-11060-58523-0029.fits
# Descargando archivo 49842 de 50000
# Descargado: spec-4658-55592-0534.fits
# Descargando archivo 49843 de 50000
# Descargado: spec-4658-55592-0487.fits
# Descargando archivo 49844 de 50000
# Descargado: spec-4661-55614-0979.fits
# Descargado: spec-0426-51882-0077.fits
# Descargando archivo 49845 de 50000
# Descargando archivo 49846 de 50000
# Descargado: spec-4661-55614-0035.fits
# Descargando archivo 49847 de 50000
# Descargado: spec-4658-55592-0494.fits
# Descargando archivo 49848 de 50000
# Descargado: spec-4661-55614-0973.fits
# Descargando archivo 49849 de 50000
# Descargado: spec-11052-58438-0473.fits
# Descargando archivo 49850 de 50000
# Descargado: spec-4661-55614-0975.fits
# Descargando archivo 49851 de 50000
# Descargado: spec-4658-55592-0531.fits
# Descargando archivo 49852 de 50000
# Descargado: spec-4658-55592-0535.fits
# Descargando archivo 49853 de 50000
# Descargado: spec-0426-51882-0112.fits
# Descargando archivo 49854 de 50000
# Descargado: spec-4661-55614-0977.fits
# Descargando archivo 49855 de 50000
# Descargado: spec-4661-55614-0037.fits
# Descargando archivo 49856 de 50000
# Descargado: spec-11052-58438-0463.fits
# Descargando archivo 49857 de 50000
# Descargado: spec-11052-58438-0467.fits
# Descargando archivo 49858 de 50000
# Descargado: spec-0429-51820-0305.fits
# Descargando archivo 49859 de 50000
# Descargado: spec-11052-58438-0464.fits
# Descargando archivo 49860 de 50000
# Descargado: spec-11052-58438-0466.fits
# Descargando archivo 49861 de 50000
# Descargado: spec-0426-51882-0071.fits
# Descargando archivo 49862 de 50000
# Descargado: spec-0426-51882-0078.fits
# Descargando archivo 49863 de 50000
# Descargado: spec-4658-55592-0477.fits
# Descargando archivo 49864 de 50000
# Descargado: spec-4661-55614-0012.fits
# Descargando archivo 49865 de 50000
# Descargado: spec-0429-51820-0309.fits
# Descargando archivo 49866 de 50000
# Descargado: spec-11052-58438-0432.fits
# Descargando archivo 49867 de 50000
# Descargado: spec-4658-55592-0476.fits
# Descargando archivo 49868 de 50000
# Descargado: spec-4661-55614-0015.fits
# Descargado: spec-4658-55592-0479.fits
# Descargando archivo 49869 de 50000
# Descargando archivo 49870 de 50000
# Descargado: spec-4658-55592-0440.fits
# Descargando archivo 49871 de 50000
# Descargado: spec-0429-51820-0304.fits
# Descargando archivo 49872 de 50000
# Descargado: spec-11052-58438-0426.fits
# Descargando archivo 49873 de 50000
# Descargado: spec-11052-58438-0430.fits
# Descargando archivo 49874 de 50000
# Descargado: spec-4658-55592-0576.fits
# Descargando archivo 49875 de 50000
# Descargado: spec-11052-58438-0382.fits
# Descargando archivo 49876 de 50000
# Descargado: spec-0429-51820-0266.fits
# Descargando archivo 49877 de 50000
# Descargado: spec-0426-51882-0068.fits
# Descargando archivo 49878 de 50000
# Descargado: spec-0429-51820-0351.fits
# Descargando archivo 49879 de 50000
# Descargado: spec-11052-58438-0389.fits
# Descargando archivo 49880 de 50000
# Descargado: spec-0429-51820-0262.fits
# Descargando archivo 49881 de 50000
# Descargado: spec-4658-55592-0398.fits
# Descargando archivo 49882 de 50000
# Descargado: spec-4658-55592-0619.fits
# Descargando archivo 49883 de 50000
# Descargado: spec-0429-51820-0354.fits
# Descargando archivo 49884 de 50000
# Descargado: spec-11052-58438-0387.fits
# Descargado: spec-0429-51820-0261.fits
# Descargando archivo 49885 de 50000
# Descargando archivo 49886 de 50000
# Descargado: spec-0426-51882-0032.fits
# Descargando archivo 49887 de 50000
# Descargado: spec-4658-55592-0617.fits
# Descargando archivo 49888 de 50000
# Descargado: spec-4658-55592-0435.fits
# Descargando archivo 49889 de 50000
# Descargado: spec-11052-58438-0344.fits
# Descargando archivo 49890 de 50000
# Descargado: spec-4658-55592-0399.fits
# Descargando archivo 49891 de 50000
# Descargado: spec-4658-55592-0657.fits
# Descargando archivo 49892 de 50000
# Descargado: spec-11052-58438-0346.fits
# Descargando archivo 49893 de 50000
# Descargado: spec-0429-51820-0400.fits
# Descargando archivo 49894 de 50000
# Descargado: spec-0426-51882-0031.fits
# Descargando archivo 49895 de 50000
# Descargado: spec-4658-55592-0358.fits
# Descargando archivo 49896 de 50000
# Descargado: spec-0426-51882-0024.fits
# Descargando archivo 49897 de 50000
# Descargado: spec-0426-51882-0038.fits
# Descargando archivo 49898 de 50000
# Descargado: spec-0426-51882-0034.fits
# Descargando archivo 49899 de 50000
# Descargado: spec-0429-51820-0277.fits
# Descargando archivo 49900 de 50000
# Descargado: spec-11052-58438-0343.fits
# Descargando archivo 49901 de 50000
# Descargado: spec-4658-55592-0655.fits
# Descargando archivo 49902 de 50000
# Descargado: spec-4658-55592-0400.fits
# Descargando archivo 49903 de 50000
# Descargado: spec-0429-51820-0263.fits
# Descargando archivo 49904 de 50000
# Descargado: spec-0429-51820-0392.fits
# Descargando archivo 49905 de 50000
# Descargado: spec-0429-51820-0223.fits
# Descargado: spec-0426-51882-0033.fits
# Descargando archivo 49906 de 50000
# Descargando archivo 49907 de 50000
# Descargado: spec-0426-51882-0037.fits
# Descargando archivo 49908 de 50000
# Descargado: spec-11052-58438-0306.fits
# Descargando archivo 49909 de 50000
# Descargado: spec-4658-55592-0356.fits
# Descargando archivo 49910 de 50000
# Descargado: spec-0429-51820-0228.fits
# Descargando archivo 49911 de 50000
# Descargado: spec-0429-51820-0221.fits
# Descargando archivo 49912 de 50000
# Descargado: spec-11052-58438-0342.fits
# Descargando archivo 49913 de 50000
# Descargado: spec-0429-51820-0227.fits
# Descargando archivo 49914 de 50000
# Descargado: spec-4658-55592-0351.fits
# Descargando archivo 49915 de 50000
# Descargado: spec-0429-51820-0196.fits
# Descargando archivo 49916 de 50000
# Descargado: spec-11052-58438-0302.fits
# Descargando archivo 49917 de 50000
# Descargado: spec-11052-58438-0341.fits
# Descargando archivo 49918 de 50000
# Descargado: spec-4658-55592-0317.fits
# Descargando archivo 49919 de 50000
# Descargado: spec-4658-55592-0740.fits
# Descargando archivo 49920 de 50000
# Descargado: spec-0429-51820-0436.fits
# Descargando archivo 49921 de 50000
# Descargado: spec-4658-55592-0315.fits
# Descargado: spec-4658-55592-0318.fits
# Descargando archivo 49922 de 50000
# Descargando archivo 49923 de 50000
# Descargado: spec-4658-55592-0320.fits
# Descargando archivo 49924 de 50000
# Descargado: spec-4658-55592-0695.fits
# Descargando archivo 49925 de 50000
# Descargado: spec-11052-58438-0261.fits
# Descargando archivo 49926 de 50000
# Descargado: spec-4658-55592-0280.fits
# Descargando archivo 49927 de 50000
# Descargado: spec-4658-55592-0271.fits
# Descargando archivo 49928 de 50000
# Descargado: spec-4658-55592-0275.fits
# Descargando archivo 49929 de 50000
# Descargado: spec-4658-55592-0276.fits
# Descargando archivo 49930 de 50000
# Descargado: spec-0429-51820-0192.fits
# Descargando archivo 49931 de 50000
# Descargado: spec-11052-58438-0263.fits
# Descargando archivo 49932 de 50000
# Descargado: spec-11052-58438-0260.fits
# Descargando archivo 49933 de 50000
# Descargado: spec-11052-58438-0230.fits
# Descargando archivo 49934 de 50000
# Descargado: spec-0429-51820-0190.fits
# Descargando archivo 49935 de 50000
# Descargado: spec-0429-51820-0191.fits
# Descargando archivo 49936 de 50000
# Descargado: spec-0429-51820-0195.fits
# Descargado: spec-11052-58438-0262.fits
# Descargando archivo 49937 de 50000
# Descargando archivo 49938 de 50000
# Descargado: spec-0429-51820-0184.fits
# Descargando archivo 49939 de 50000
# Descargado: spec-4658-55592-0277.fits
# Descargando archivo 49940 de 50000
# Descargado: spec-0429-51820-0193.fits
# Descargando archivo 49941 de 50000
# Descargado: spec-11052-58438-0225.fits
# Descargando archivo 49942 de 50000
# Descargado: spec-11052-58438-0222.fits
# Descargado: spec-4658-55592-0279.fits
# Descargando archivo 49943 de 50000
# Descargando archivo 49944 de 50000
# Descargado: spec-4658-55592-0278.fits
# Descargando archivo 49945 de 50000
# Descargado: spec-11052-58438-0224.fits
# Descargando archivo 49946 de 50000
# Descargado: spec-4658-55592-0232.fits
# Descargando archivo 49947 de 50000
# Descargado: spec-4658-55592-0226.fits
# Descargando archivo 49948 de 50000
# Descargado: spec-11052-58438-0209.fits
# Descargado: spec-4658-55592-0236.fits
# Descargando archivo 49949 de 50000
# Descargando archivo 49950 de 50000
# Descargado: spec-4658-55592-0237.fits
# Descargando archivo 49951 de 50000
# Descargado: spec-4658-55592-0238.fits
# Descargado: spec-4658-55592-0239.fits
# Descargando archivo 49952 de 50000
# Descargando archivo 49953 de 50000
# Descargado: spec-4658-55592-0235.fits
# Descargando archivo 49954 de 50000
# Descargado: spec-4658-55592-0197.fits
# Descargando archivo 49955 de 50000
# Descargado: spec-11052-58438-0184.fits
# Descargando archivo 49956 de 50000
# Descargado: spec-4658-55592-0198.fits
# Descargando archivo 49957 de 50000
# Descargado: spec-0429-51820-0173.fits
# Descargando archivo 49958 de 50000
# Descargado: spec-4658-55592-0191.fits
# Descargando archivo 49959 de 50000
# Descargado: spec-0429-51820-0175.fits
# Descargando archivo 49960 de 50000
# Descargado: spec-0429-51820-0166.fits
# Descargando archivo 49961 de 50000
# Descargado: spec-11052-58438-0217.fits
# Descargando archivo 49962 de 50000
# Descargado: spec-0429-51820-0177.fits
# Descargando archivo 49963 de 50000
# Descargado: spec-0429-51820-0198.fits
# Descargando archivo 49964 de 50000
# Descargado: spec-4658-55592-0160.fits
# Descargando archivo 49965 de 50000
# Descargado: spec-0429-51820-0176.fits
# Descargando archivo 49966 de 50000
# Descargado: spec-11052-58438-0223.fits
# Descargando archivo 49967 de 50000
# Descargado: spec-0429-51820-0174.fits
# Descargando archivo 49968 de 50000
# Descargado: spec-4658-55592-0153.fits
# Descargando archivo 49969 de 50000
# Descargado: spec-0429-51820-0164.fits
# Descargando archivo 49970 de 50000
# Descargado: spec-11052-58438-0185.fits
# Descargando archivo 49971 de 50000
# Descargado: spec-0429-51820-0171.fits
# Descargando archivo 49972 de 50000
# Descargado: spec-4658-55592-0196.fits
# Descargando archivo 49973 de 50000
# Descargado: spec-0429-51820-0155.fits
# Descargando archivo 49974 de 50000
# Descargado: spec-11052-58438-0177.fits
# Descargando archivo 49975 de 50000
# Descargado: spec-0429-51820-0148.fits
# Descargando archivo 49976 de 50000
# Descargado: spec-4658-55592-0195.fits
# Descargando archivo 49977 de 50000
# Descargado: spec-0429-51820-0153.fits
# Descargando archivo 49978 de 50000
# Descargado: spec-11052-58438-0219.fits
# Descargando archivo 49979 de 50000
# Descargado: spec-0429-51820-0157.fits
# Descargando archivo 49980 de 50000
# Descargado: spec-4658-55592-0194.fits
# Descargando archivo 49981 de 50000
# Descargado: spec-4658-55592-0157.fits
# Descargando archivo 49982 de 50000
# Descargado: spec-4658-55592-0159.fits
# Descargando archivo 49983 de 50000
# Descargado: spec-0429-51820-0152.fits
# Descargando archivo 49984 de 50000
# Descargado: spec-11052-58438-0132.fits
# Descargando archivo 49985 de 50000
# Descargado: spec-4658-55592-0151.fits
# Descargando archivo 49986 de 50000
# Descargado: spec-4658-55592-0136.fits
# Descargando archivo 49987 de 50000
# Descargado: spec-0429-51820-0159.fits
# Descargando archivo 49988 de 50000
# Descargado: spec-0429-51820-0160.fits
# Descargando archivo 49989 de 50000
# Descargado: spec-11052-58438-0146.fits
# Descargando archivo 49990 de 50000
# Descargado: spec-0429-51820-0143.fits
# Descargando archivo 49991 de 50000
# Descargado: spec-4658-55592-0155.fits
# Descargando archivo 49992 de 50000
# Descargado: spec-4658-55592-0158.fits
# Descargado: spec-11052-58438-0173.fits
# Descargando archivo 49993 de 50000
# Descargando archivo 49994 de 50000
# Descargado: spec-4658-55592-0152.fits
# Descargando archivo 49995 de 50000
# Descargado: spec-11052-58438-0179.fits
# Descargando archivo 49996 de 50000
# Descargado: spec-4658-55592-0134.fits
# Descargando archivo 49997 de 50000
# Descargado: spec-11052-58438-0140.fits
# Descargando archivo 49998 de 50000
# Descargado: spec-11052-58438-0138.fits
# Descargando archivo 49999 de 50000
# Descargado: spec-4658-55592-0135.fits
# Descargando archivo 50000 de 50000
# Descarga finalizada
