# %%
import os
import sys
import random
from astropy.io import fits
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
while True:
    def expand_points(wavelength, flux, target_count):
        wl = list(wavelength)
        fl = list(flux)
        diffs = [abs(fl[i+1] - fl[i]) for i in range(len(fl)-1)]
        sorted_indices = sorted(range(len(diffs)), key=lambda i: diffs[i], reverse=True)
        
        while len(wl) < target_count:
            for idx in sorted_indices:
                if len(wl) >= target_count:
                    break
                new_wl = (wl[idx] + wl[idx+1]) / 2
                new_fl = (fl[idx] + fl[idx+1]) / 2
                wl.insert(idx+1, new_wl)
                fl.insert(idx+1, new_fl)
        
        return np.array(wl), np.array(fl)

    # Cargar la lista estática de archivos FITS
    files_list_file = 'extra/files_list.pkl'
    with open(files_list_file, 'rb') as f:
        files = pickle.load(f)

    # Ruta a la carpeta con los archivos FITS a procesar
    folder_path = r'spectrums'
    batch_size = 10000  # Número de archivos a procesar por lote
    index_file = "extra/batch_index_a.txt"

    # Verificar que el archivo exista y contenga un número entero
    if not os.path.exists(index_file):
        print(f"Error: El archivo {index_file} no existe. Deteniendo la ejecución.")
        sys.exit(1)

    with open(index_file, "r") as f:
        content = f.read().strip()
        try:
            batch_index = int(content)
        except ValueError:
            print(f"Error: El archivo {index_file} no contiene un número entero válido. Deteniendo la ejecución.")
            sys.exit(1)

    # Calcular los índices del lote actual (recorrer 10k archivos)
    start_index = (batch_index - 1) * batch_size
    # end_index es el mínimo entre el cálculo y la longitud total de la lista
    end_index = min(batch_index * batch_size - 1, len(files))

    # Finalización
    if batch_index > 30:
        print("Hemos procesado los 300,000 del lote.")
        sys.exit(0)

    if start_index >= len(files):
        print("Todos los archivos han sido procesados.")
        sys.exit(0)

    # Seleccionar el lote actual (serán 10,000 archivos, o menos si es el último lote)
    current_batch = files[start_index:end_index]

    spectra_data = {}
    i = 0

    for filename in current_batch:
        file_path = os.path.join(folder_path, filename)
        try:
            with fits.open(file_path) as hdul:
                # Verificar que el archivo tenga las extensiones esperadas
                if len(hdul) > 2:
                    flux_data = hdul[1].data["flux"]         # Datos de flujo
                    loglam_data = hdul[1].data["loglam"]        # Datos de log(lambda)
                    wavelength_data = 10 ** loglam_data         # Convertir log(lambda) a longitud de onda
                    redshift = hdul[2].data["Z"][0]             # Extraer redshift
                    
                    # Aplicar la interpolación para obtener 5000 puntos
                    interp_wavelength, interp_flux = expand_points(wavelength_data, flux_data, target_count=5000)
                    
                    # Guardar los datos en el diccionario
                    spectra_data[filename] = {
                        "wavelength": interp_wavelength,
                        "flux": interp_flux,
                        "redshift": redshift
                    }
                    
                    i += 1
                    if i % 1000 == 0:
                        print(f"Procesado {filename} ({i})")
        except Exception as e:
            print(f"Error procesando {filename}: {e}")

    print(f"Se procesaron {len(spectra_data)} archivos FITS en el lote {batch_index}.")

    # Guardar el diccionario con los datos procesados en un archivo pickle
    output_file = f'data/spectra_data_complete{batch_index}.pkl'
    with open(output_file, 'wb') as f:
        pickle.dump(spectra_data, f)
    print(f"Datos guardados en {output_file}")

    # Guardar la lista de archivos procesados en este lote
    batch_list_file = f'extra/batch_files_list{batch_index}.pkl'
    with open(batch_list_file, 'wb') as f:
        pickle.dump(current_batch, f)
    print(f"Lista de archivos del lote {batch_index} guardada en {batch_list_file}")

    # Actualizar el archivo batch_index_a.txt para la siguiente iteración
    batch_index += 1
    with open(index_file, "w") as f:
        f.write(str(batch_index))

    print("Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice",
        f"{(batch_index - 1) * batch_size} hasta {min(batch_index * batch_size -1, len(files))}.")
# Out:
# Procesado spec-0308-51662-0379.fits (1000)
# Procesado spec-0310-51990-0556.fits (2000)
# Procesado spec-0312-51689-0568.fits (3000)
# Procesado spec-0326-52375-0259.fits (4000)
# Procesado spec-0328-52282-0362.fits (5000)
# Procesado spec-0330-52370-0311.fits (6000)
# Procesado spec-0332-52367-0346.fits (7000)
# Procesado spec-0334-51993-0382.fits (8000)
# Procesado spec-0336-51999-0442.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 3.
# Datos guardados en data/spectra_data_complete3.pkl
# Lista de archivos del lote 3 guardada en extra/batch_files_list3.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 30000 hasta 39999.
# Procesado spec-0340-51990-0533.fits (1000)
# Procesado spec-0342-51691-0610.fits (2000)
# Procesado spec-0345-51690-0103.fits (3000)
# Procesado spec-0348-51671-0297.fits (4000)
# Procesado spec-0350-51691-0472.fits (5000)
# Procesado spec-0352-51694-0534.fits (6000)
# Procesado spec-0355-51788-0050.fits (7000)
# Procesado spec-0359-51821-0169.fits (8000)
# Procesado spec-0363-51989-0397.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 4.
# Datos guardados en data/spectra_data_complete4.pkl
# Lista de archivos del lote 4 guardada en extra/batch_files_list4.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 40000 hasta 49999.
# Procesado spec-0372-52173-0312.fits (1000)
# Procesado spec-0375-52140-0242.fits (2000)
# Procesado spec-0377-52145-0564.fits (3000)
# Procesado spec-0380-51792-0219.fits (4000)
# Procesado spec-0383-51818-0073.fits (5000)
# Procesado spec-0385-51783-0300.fits (6000)
# Procesado spec-0387-51791-0635.fits (7000)
# Procesado spec-0390-51900-0145.fits (8000)
# Procesado spec-0392-51793-0171.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 5.
# Datos guardados en data/spectra_data_complete5.pkl
# Lista de archivos del lote 5 guardada en extra/batch_files_list5.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 50000 hasta 59999.
# Procesado spec-0396-51816-0258.fits (1000)
# Procesado spec-0398-51789-0271.fits (2000)
# Procesado spec-0400-51820-0329.fits (3000)
# Procesado spec-0402-51793-0404.fits (4000)
# Procesado spec-0404-51812-0523.fits (5000)
# Procesado spec-0407-51820-0474.fits (6000)
# Procesado spec-0410-51877-0400.fits (7000)
# Procesado spec-0412-52258-0470.fits (8000)
# Procesado spec-0415-51810-0196.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 6.
# Datos guardados en data/spectra_data_complete6.pkl
# Lista de archivos del lote 6 guardada en extra/batch_files_list6.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 60000 hasta 69999.
# Procesado spec-0420-51871-0251.fits (1000)
# Procesado spec-0422-51811-0236.fits (2000)
# Procesado spec-0424-51893-0147.fits (3000)
# Procesado spec-0426-51882-0221.fits (4000)
# Procesado spec-0428-51883-0324.fits (5000)
# Procesado spec-0430-51877-0325.fits (6000)
# Procesado spec-0432-51884-0533.fits (7000)
# Procesado spec-0435-51882-0172.fits (8000)
# Procesado spec-0437-51876-0433.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 7.
# Datos guardados en data/spectra_data_complete7.pkl
# Lista de archivos del lote 7 guardada en extra/batch_files_list7.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 70000 hasta 79999.
# Procesado spec-0442-51882-0011.fits (1000)
# Procesado spec-0443-51873-0625.fits (2000)
# Procesado spec-0445-51873-0567.fits (3000)
# Procesado spec-0447-51877-0496.fits (4000)
# Procesado spec-0449-51900-0452.fits (5000)
# Procesado spec-0451-51908-0427.fits (6000)
# Procesado spec-0454-51908-0139.fits (7000)
# Procesado spec-0456-51910-0220.fits (8000)
# Procesado spec-0458-51929-0318.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 8.
# Datos guardados en data/spectra_data_complete8.pkl
# Lista de archivos del lote 8 guardada en extra/batch_files_list8.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 80000 hasta 89999.
# Procesado spec-0462-51909-0440.fits (1000)
# Procesado spec-0464-51908-0360.fits (2000)
# Procesado spec-0467-51901-0403.fits (3000)
# Procesado spec-0470-51929-0048.fits (4000)
# Procesado spec-0472-51955-0571.fits (5000)
# Procesado spec-0475-51965-0232.fits (6000)
# Procesado spec-0477-52026-0400.fits (7000)
# Procesado spec-0483-51924-0302.fits (8000)
# Procesado spec-0485-51909-0511.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 9.
# Datos guardados en data/spectra_data_complete9.pkl
# Lista de archivos del lote 9 guardada en extra/batch_files_list9.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 90000 hasta 99999.
# Procesado spec-0490-51929-0007.fits (1000)
# Procesado spec-0491-51942-0618.fits (2000)
# Procesado spec-0493-51957-0565.fits (3000)
# Procesado spec-0495-51988-0487.fits (4000)
# Procesado spec-0497-51989-0474.fits (5000)
# Procesado spec-0499-51988-0564.fits (6000)
# Procesado spec-0502-51957-0131.fits (7000)
# Procesado spec-0504-52316-0169.fits (8000)
# Procesado spec-0506-52022-0165.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 10.
# Datos guardados en data/spectra_data_complete10.pkl
# Lista de archivos del lote 10 guardada en extra/batch_files_list10.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 100000 hasta 109999.
# Procesado spec-0510-52381-0119.fits (1000)
# Procesado spec-0512-51992-0033.fits (2000)
# Procesado spec-0513-51989-0571.fits (3000)
# Procesado spec-0515-52051-0510.fits (4000)
# Procesado spec-0517-52024-0407.fits (5000)
# Procesado spec-0519-52283-0345.fits (6000)
# Procesado spec-0521-52326-0317.fits (7000)
# Procesado spec-0523-52026-0377.fits (8000)
# Procesado spec-0525-52295-0473.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 11.
# Datos guardados en data/spectra_data_complete11.pkl
# Lista de archivos del lote 11 guardada en extra/batch_files_list11.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 110000 hasta 119999.
# Procesado spec-0529-52025-0413.fits (1000)
# Procesado spec-0531-52028-0452.fits (2000)
# Procesado spec-0533-51994-0496.fits (3000)
# Procesado spec-0535-51999-0499.fits (4000)
# Procesado spec-0538-52029-0275.fits (5000)
# Procesado spec-0540-51996-0576.fits (6000)
# Procesado spec-0543-52017-0244.fits (7000)
# Procesado spec-0545-52202-0300.fits (8000)
# Procesado spec-0547-51959-0552.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 12.
# Datos guardados en data/spectra_data_complete12.pkl
# Lista de archivos del lote 12 guardada en extra/batch_files_list12.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 120000 hasta 129999.
# Procesado spec-0552-51992-0252.fits (1000)
# Procesado spec-0554-52000-0179.fits (2000)
# Procesado spec-0556-51991-0229.fits (3000)
# Procesado spec-0558-52317-0538.fits (4000)
# Procesado spec-0561-52295-0118.fits (5000)
# Procesado spec-0565-52225-0299.fits (6000)
# Procesado spec-0567-52252-0422.fits (7000)
# Procesado spec-0569-52264-0438.fits (8000)
# Procesado spec-0571-52286-0615.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 13.
# Datos guardados en data/spectra_data_complete13.pkl
# Lista de archivos del lote 13 guardada en extra/batch_files_list13.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 130000 hasta 139999.
# Procesado spec-0576-52325-0160.fits (1000)
# Procesado spec-0578-52339-0093.fits (2000)
# Procesado spec-0580-52368-0059.fits (3000)
# Procesado spec-0582-52045-0004.fits (4000)
# Procesado spec-0583-52055-0628.fits (5000)
# Procesado spec-0586-52023-0075.fits (6000)
# Procesado spec-0588-52045-0079.fits (7000)
# Procesado spec-0590-52057-0057.fits (8000)
# Procesado spec-0591-52022-0581.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 14.
# Datos guardados en data/spectra_data_complete14.pkl
# Lista de archivos del lote 14 guardada en extra/batch_files_list14.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 140000 hasta 149999.
# Procesado spec-0596-52370-0126.fits (1000)
# Procesado spec-0598-52316-0336.fits (2000)
# Procesado spec-0600-52317-0332.fits (3000)
# Procesado spec-0602-52072-0292.fits (4000)
# Procesado spec-0604-52079-0376.fits (5000)
# Procesado spec-0606-52365-0461.fits (6000)
# Procesado spec-0608-52081-0512.fits (7000)
# Procesado spec-0611-52055-0198.fits (8000)
# Procesado spec-0613-52345-0390.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 15.
# Datos guardados en data/spectra_data_complete15.pkl
# Lista de archivos del lote 15 guardada en extra/batch_files_list15.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 150000 hasta 159999.
# Procesado spec-0617-52072-0459.fits (1000)
# Procesado spec-0619-52056-0414.fits (2000)
# Procesado spec-0621-52055-0419.fits (3000)
# Procesado spec-0623-52051-0430.fits (4000)
# Procesado spec-0625-52145-0442.fits (5000)
# Procesado spec-0627-52144-0419.fits (6000)
# Procesado spec-0629-52051-0414.fits (7000)
# Procesado spec-0631-52079-0385.fits (8000)
# Procesado spec-0633-52079-0395.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 16.
# Datos guardados en data/spectra_data_complete16.pkl
# Lista de archivos del lote 16 guardada en extra/batch_files_list16.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 160000 hasta 169999.
# Procesado spec-0638-52081-0270.fits (1000)
# Procesado spec-0640-52200-0328.fits (2000)
# Procesado spec-0644-52173-0389.fits (3000)
# Procesado spec-0646-52523-0378.fits (4000)
# Procesado spec-0648-52559-0322.fits (5000)
# Procesado spec-0650-52143-0276.fits (6000)
# Procesado spec-0652-52138-0268.fits (7000)
# Procesado spec-0654-52146-0291.fits (8000)
# Procesado spec-0656-52148-0192.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 17.
# Datos guardados en data/spectra_data_complete17.pkl
# Lista de archivos del lote 17 guardada en extra/batch_files_list17.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 170000 hasta 179999.
# Procesado spec-0659-52199-0620.fits (1000)
# Procesado spec-0662-52147-0020.fits (2000)
# Procesado spec-0664-52174-0022.fits (3000)
# Procesado spec-0665-52168-0587.fits (4000)
# Procesado spec-0667-52163-0494.fits (5000)
# Procesado spec-0669-52559-0523.fits (6000)
# Procesado spec-0671-52206-0493.fits (7000)
# Procesado spec-0675-52590-0065.fits (8000)
# Procesado spec-0677-52606-0638.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 18.
# Datos guardados en data/spectra_data_complete18.pkl
# Lista de archivos del lote 18 guardada en extra/batch_files_list18.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 180000 hasta 189999.
# Procesado spec-0684-52523-0237.fits (1000)
# Procesado spec-0687-52518-0113.fits (2000)
# Procesado spec-0690-52261-0056.fits (3000)
# Procesado spec-0693-52254-0152.fits (4000)
# Procesado spec-0696-52209-0081.fits (5000)
# Procesado spec-0699-52202-0216.fits (6000)
# Procesado spec-0702-52178-0198.fits (7000)
# Procesado spec-0706-52199-0194.fits (8000)
# Procesado spec-0710-52203-0085.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 19.
# Datos guardados en data/spectra_data_complete19.pkl
# Lista de archivos del lote 19 guardada en extra/batch_files_list19.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 190000 hasta 199999.
# Procesado spec-0716-52203-0215.fits (1000)
# Procesado spec-0718-52206-0213.fits (2000)
# Procesado spec-0720-52206-0155.fits (3000)
# Procesado spec-0722-52224-0176.fits (4000)
# Procesado spec-0724-52254-0215.fits (5000)
# Procesado spec-0726-52226-0221.fits (6000)
# Procesado spec-0728-52520-0639.fits (7000)
# Procesado spec-0731-52460-0370.fits (8000)
# Procesado spec-0734-52224-0007.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 20.
# Datos guardados en data/spectra_data_complete20.pkl
# Lista de archivos del lote 20 guardada en extra/batch_files_list20.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 200000 hasta 209999.
# Procesado spec-0738-52521-0215.fits (1000)
# Procesado spec-0740-52263-0314.fits (2000)
# Procesado spec-0742-52263-0337.fits (3000)
# Procesado spec-0744-52251-0339.fits (4000)
# Procesado spec-0746-52238-0322.fits (5000)
# Procesado spec-0748-52233-0328.fits (6000)
# Procesado spec-0750-52235-0255.fits (7000)
# Procesado spec-0752-52251-0196.fits (8000)
# Procesado spec-0754-52232-0382.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 21.
# Datos guardados en data/spectra_data_complete21.pkl
# Lista de archivos del lote 21 guardada en extra/batch_files_list21.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 210000 hasta 219999.
# Procesado spec-0759-52254-0120.fits (1000)
# Procesado spec-0761-54524-0225.fits (2000)
# Procesado spec-0763-52235-0395.fits (3000)
# Procesado spec-0765-52254-0427.fits (4000)
# Procesado spec-0767-52252-0447.fits (5000)
# Procesado spec-0769-54530-0589.fits (6000)
# Procesado spec-0772-52375-0125.fits (7000)
# Procesado spec-0774-52286-0478.fits (8000)
# Procesado spec-0776-52319-0630.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 22.
# Datos guardados en data/spectra_data_complete22.pkl
# Lista de archivos del lote 22 guardada en extra/batch_files_list22.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 220000 hasta 229999.
# Procesado spec-0781-52373-0353.fits (1000)
# Procesado spec-0783-52325-0467.fits (2000)
# Procesado spec-0785-52339-0556.fits (3000)
# Procesado spec-0788-52338-0173.fits (4000)
# Procesado spec-0790-52441-0277.fits (5000)
# Procesado spec-0792-52353-0386.fits (6000)
# Procesado spec-0794-52376-0522.fits (7000)
# Procesado spec-0797-52263-0271.fits (8000)
# Procesado spec-0804-52266-0125.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 23.
# Datos guardados en data/spectra_data_complete23.pkl
# Lista de archivos del lote 23 guardada en extra/batch_files_list23.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 230000 hasta 239999.
# Procesado spec-0808-52556-0363.fits (1000)
# Procesado spec-0810-52672-0316.fits (2000)
# Procesado spec-0812-52352-0452.fits (3000)
# Procesado spec-0814-52443-0625.fits (4000)
# Procesado spec-0817-52381-0019.fits (5000)
# Procesado spec-0819-52409-0259.fits (6000)
# Procesado spec-0825-52289-0608.fits (7000)
# Procesado spec-0828-52317-0116.fits (8000)
# Procesado spec-0830-52293-0205.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 24.
# Datos guardados en data/spectra_data_complete24.pkl
# Lista de archivos del lote 24 guardada en extra/batch_files_list24.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 240000 hasta 249999.
# Procesado spec-0835-52326-0173.fits (1000)
# Procesado spec-0837-52642-0199.fits (2000)
# Procesado spec-0839-52373-0153.fits (3000)
# Procesado spec-0841-52375-0053.fits (4000)
# Procesado spec-0843-52378-0009.fits (5000)
# Procesado spec-0844-52378-0617.fits (6000)
# Procesado spec-0846-52407-0593.fits (7000)
# Procesado spec-0849-52439-0002.fits (8000)
# Procesado spec-0850-52338-0588.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 25.
# Datos guardados en data/spectra_data_complete25.pkl
# Lista de archivos del lote 25 guardada en extra/batch_files_list25.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 250000 hasta 259999.
# Procesado spec-0854-52373-0594.fits (1000)
# Procesado spec-0856-52339-0545.fits (2000)
# Procesado spec-0859-52317-0287.fits (3000)
# Procesado spec-0861-52318-0590.fits (4000)
# Procesado spec-0865-52323-0182.fits (5000)
# Procesado spec-0872-52339-0472.fits (6000)
# Procesado spec-0874-52338-0421.fits (7000)
# Procesado spec-0876-52669-0521.fits (8000)
# Procesado spec-0878-52353-0522.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 26.
# Datos guardados en data/spectra_data_complete26.pkl
# Lista de archivos del lote 26 guardada en extra/batch_files_list26.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 260000 hasta 269999.
# Procesado spec-0882-52370-0551.fits (1000)
# Procesado spec-0884-52374-0637.fits (2000)
# Procesado spec-0887-52376-0097.fits (3000)
# Procesado spec-0889-52663-0467.fits (4000)
# Procesado spec-0891-52584-0552.fits (5000)
# Procesado spec-0893-52589-0566.fits (6000)
# Procesado spec-0895-52581-0544.fits (7000)
# Procesado spec-0898-52606-0143.fits (8000)
# Procesado spec-0900-52637-0510.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 27.
# Datos guardados en data/spectra_data_complete27.pkl
# Lista de archivos del lote 27 guardada en extra/batch_files_list27.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 270000 hasta 279999.
# Procesado spec-0905-52643-0126.fits (1000)
# Procesado spec-0907-52373-0114.fits (2000)
# Procesado spec-0909-52379-0047.fits (3000)
# Procesado spec-0911-52426-0019.fits (4000)
# Procesado spec-0913-52433-0081.fits (5000)
# Procesado spec-0915-52443-0247.fits (6000)
# Procesado spec-0917-52400-0437.fits (7000)
# Procesado spec-0919-52409-0634.fits (8000)
# Procesado spec-0922-52426-0360.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 28.
# Datos guardados en data/spectra_data_complete28.pkl
# Lista de archivos del lote 28 guardada en extra/batch_files_list28.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 280000 hasta 289999.
# Procesado spec-0927-52577-0485.fits (1000)
# Procesado spec-0930-52618-0102.fits (2000)
# Procesado spec-0932-52620-0279.fits (3000)
# Procesado spec-0934-52672-0462.fits (4000)
# Procesado spec-0936-52705-0487.fits (5000)
# Procesado spec-0938-52708-0639.fits (6000)
# Procesado spec-0941-52709-0086.fits (7000)
# Procesado spec-0943-52376-0251.fits (8000)
# Procesado spec-0945-52652-0370.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 29.
# Datos guardados en data/spectra_data_complete29.pkl
# Lista de archivos del lote 29 guardada en extra/batch_files_list29.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 290000 hasta 299999.
# Procesado spec-0949-52427-0385.fits (1000)
# Procesado spec-0951-52398-0383.fits (2000)
# Procesado spec-0953-52411-0575.fits (3000)
# Procesado spec-0955-52409-0511.fits (4000)
# Procesado spec-0957-52398-0594.fits (5000)
# Procesado spec-0959-52411-0523.fits (6000)
# Procesado spec-0961-52615-0444.fits (7000)
# Procesado spec-0963-52643-0430.fits (8000)
# Procesado spec-0965-52438-0391.fits (9000)
# Se procesaron 9999 archivos FITS en el lote 30.
# Datos guardados en data/spectra_data_complete30.pkl
# Lista de archivos del lote 30 guardada en extra/batch_files_list30.pkl
# Proceso completado para este lote. Para el siguiente lote, se procesarán los archivos desde el índice 300000 hasta 309999.
# Hemos procesado los 300,000 del lote.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\alfa\anaconda3\envs\TFG\Lib\site-packages\IPython\core\interactiveshell.py:3557: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
