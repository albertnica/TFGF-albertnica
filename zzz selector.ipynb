# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Directorio donde se encuentra el archivo memmap
dst_folder = "data"
redshift_dat_filename = "spectra_data_100k_redshift_mmap.dat"
redshift_dat_path = os.path.join(dst_folder, redshift_dat_filename)

# Número total de espectros
total_spectra = 100000

# Cargar el memmap en modo lectura
redshift_memmap = np.memmap(redshift_dat_path, dtype='float32', mode='r', shape=(total_spectra,))

# Convertir a array de NumPy
redshift_array = np.array(redshift_memmap)

# Definir los bins para el histograma (ancho de bin = 0.1)
bins = np.arange(0, redshift_array.max() + 0.1, 0.1)

# Crear y mostrar el histograma
plt.figure(figsize=(18, 16))
plt.hist(redshift_array, bins=bins, color='skyblue', edgecolor='black')
plt.xlabel("Redshift")
plt.ylabel("Número de espectros")
plt.title("Histograma de redshifts (ancho de bin = 0.1)")
plt.xlim(0, 7.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 total_spectra = 100000
#      13 # Cargar el memmap en modo lectura
# ---> 14 redshift_memmap = np.memmap(redshift_dat_path, dtype='float32', mode='r', shape=(total_spectra,))
#      16 # Convertir a array de NumPy
#      17 redshift_array = np.array(redshift_memmap)
#
# File c:\Users\alfa\anaconda3\envs\TFGF\Lib\site-packages\numpy\_core\memmap.py:234, in memmap.__new__(subtype, filename, dtype, mode, offset, shape, order)
#     232     f_ctx = nullcontext(filename)
#     233 else:
# --> 234     f_ctx = open(
#     235         os.fspath(filename),
#     236         ('r' if mode == 'c' else mode)+'b'
#     237     )
#     239 with f_ctx as fid:
#     240     fid.seek(0, 2)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'spectrums training 100k\\spectra_data_100k_redshift_mmap.dat'
